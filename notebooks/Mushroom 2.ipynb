# %%
# %matplotlib inline

import numpy as np
import itertools

import torch
import torch.nn as nn
import torch.optim as optim

import random
import matplotlib
import matplotlib.pyplot as plt
from tqdm import tqdm, tqdm_notebook

# %%
# set random seed to 0
np.random.seed(0)
torch.manual_seed(0)
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
def create_data(prefix_chars, suffix_chars, prefix_length, suffix_length):
    """
    prefix_chars: iterable
    suffix_chars: iterable
    prefix_length: int
    suffix_length: int
    return: take every possible combination of prefixes of length prefix_length
        and take every possible combination of suffixies of length suffix_length,
        then create every possible combination of those.
        Generates len(prefix_chars)^prefix_length * len(suffix_chars)^suffix_length
    """
    prefixes = list(itertools.product(prefix_chars, repeat=prefix_length))
    suffixes = list(itertools.product(suffix_chars, repeat=suffix_length))
    return [p + s for p, s in itertools.product(prefixes, suffixes)]
    
def vectorize_2d(seq, vocab_size):
    vectors = np.zeros((len(seq), vocab_size), dtype=np.float64)
    for i in range(len(seq)):
        vectors[i][seq[i]] = 1
    return torch.tensor(vectors)

# %%
def create_output(seq):
    """
    pointer: index to inspect next (attention direction)
    task1: cur^2 mod n (rule-learning)
    task2: value of right-neighbor (attention direction, holding memory, write vs. no write)
    task3: sum of self and left and right neighbors, mod n (combination of tasks 1 and 2)
    """
    pointer_outputs = []
    task1_outputs = []
    task2_outputs = []
    task3_outputs = []
    
    cur = 0
    for i in range(len(seq)):
        
        task1_out = (seq[cur]**2)%len(seq)
        task2_out = seq[(cur+1)%len(seq)]
        
        task3_prev = seq[(cur-1)%len(seq)]
        task3_next = seq[(cur+1)%len(seq)]
        task3_out = (task3_prev + seq[cur] + task3_next)%len(seq)
        
        cur = seq[cur]
        pointer_outputs.append(cur)
        task1_outputs.append(task1_out)
        task2_outputs.append(task2_out)
        task3_outputs.append(task3_out)
        
    return torch.tensor(pointer_outputs), torch.tensor(task1_outputs), torch.tensor(task2_outputs), torch.tensor(task3_outputs)

# %%
def training_sequence_1(seq):
    """
    Trains goto, task1, and task2. e.g.
    Iter 1: Compute task 1, move to i=1 to perform task 2
        Input: seq[0]
        Goto: 1
        Task 1: seq[0]^2
        Task 2: No-op
    Iter 2: Compute task 2, move to i=seq[0] to perform task 1
        Input: seq[1]
        Goto: seq[0]
        Task 1: No-op
        Task 2: seq[1]
    etc...
    """
    n = len(seq)
    no_op = len(seq)
    pointer_outputs, task1_outputs, task2_outputs, task3_outputs = create_output(seq)
    X, Y1, Y2, Y3 = [], [], [], []
    index = 0
    for i in range(n):
        X.append(seq[index])
        X.append(seq[(index+1)%n])
        Y1.append((index+1)%n)
        Y1.append(pointer_outputs[i])
        Y2.append(task1_outputs[i])
        Y2.append(no_op)
        Y3.append(no_op)
        Y3.append(task2_outputs[i])
        index = pointer_outputs[i]
    return torch.tensor(X), torch.tensor(Y1), torch.tensor(Y2), torch.tensor(Y3)

# %%
class Model1(nn.Module):
    def __init__(self, input_dim, pointer_dim, task1_dim, task2_dim, hidden_layer_size):
        super(Model1, self).__init__()
        self.input_dim = input_dim
        self.pointer_dim = pointer_dim
        self.task1_dim = task1_dim
        self.task2_dim = task2_dim
        self.hidden_layer_size = hidden_layer_size
        
        self.lstm = nn.LSTMCell(input_dim, hidden_layer_size)
        self.lin_pointer = nn.Linear(hidden_layer_size, pointer_dim)
        self.lin_task1 = nn.Linear(hidden_layer_size, task1_dim)
        self.lin_task2 = nn.Linear(hidden_layer_size, task2_dim)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        pointer_outputs, task1_outputs, task2_outputs = [], [], []
        h_t = torch.zeros(1, self.hidden_layer_size, dtype=torch.double)
        c_t = torch.zeros(1, self.hidden_layer_size, dtype=torch.double)
        
        for x_t in x.reshape(len(x), 1, self.input_dim):
            h_t, c_t = self.lstm(x_t, (h_t, c_t))
            pointer_outputs.append(self.softmax(self.lin_pointer(h_t)))
            task1_outputs.append(self.softmax(self.lin_task1(h_t)))
            task2_outputs.append(self.softmax(self.lin_task2(h_t)))
        
        return torch.stack(pointer_outputs).reshape(len(x), self.pointer_dim), \
                torch.stack(task1_outputs).reshape(len(x), self.task1_dim), \
                torch.stack(task2_outputs).reshape(len(x), self.task2_dim)

# %%
max_digit = 7
split = 4
train_data = create_data(range(split), range(split, max_digit), split, max_digit-split)
X, Y1, Y2, Y3 = [], [], [], []
for datum in train_data:
    inputs, pointer_outputs, task1_outputs, task2_outputs = training_sequence_1(datum)
    X.append(vectorize_2d(inputs, max_digit))
    Y1.append(pointer_outputs)
    Y2.append(task1_outputs)
    Y3.append(task2_outputs)

# %%
model = Model1(max_digit, max_digit, max_digit+1, max_digit+1, 30)
model.double()
optimizer = optim.Adam(model.parameters())

closures = []

for i in range(len(X)):
    x, y1, y2, y3 = X[i], Y1[i], Y2[i], Y3[i]
    def closure():
        optimizer.zero_grad()
        pred1, pred2, pred3 = model(x)
        pointer_loss = nn.functional.nll_loss(pred1, pointer_outputs)
        task1_loss = nn.functional.nll_loss(pred2, task1_outputs)
        task2_loss = nn.functional.nll_loss(pred3, task2_outputs)
        loss = pointer_loss + task1_loss + task2_loss

        loss.backward()
        return loss
    closures.append(closure)

# %%
for i in tqdm_notebook(range(10)):
    total_loss = 0
    random.shuffle(closures)
    for closure in closures:
        total_loss += float(optimizer.step(closure))
    print(total_loss)
# Out:
# -20158.072274769343
# -20735.874594785273
# -20735.996443550714
# -20735.999879440817
# -20735.999989012507
# -20735.999995948823
# -20735.999997528943
# -20735.999998216656
# -20735.999998603515
# -20735.99999885207

# %%
model = Model1(7, 7, 8, 8, 30)
model.double()

optimizer = optim.Adam(model.parameters())
inputs, pointer_outputs, task1_outputs, task2_outputs = training_sequence_1([2,4,6,0,5,3,1])
X = vectorize_2d(inputs, 7)
Y1 = vectorize_2d(pointer_outputs, 7)
Y2 = vectorize_2d(task1_outputs, 8)
Y3 = vectorize_2d(task2_outputs, 8)

def closure():
    optimizer.zero_grad()
    pred1, pred2, pred3 = model(X)
    pointer_loss = nn.functional.nll_loss(pred1, pointer_outputs)
    task1_loss = nn.functional.nll_loss(pred2, task1_outputs)
    task2_loss = nn.functional.nll_loss(pred3, task2_outputs)
    loss = pointer_loss + task1_loss + task2_loss
    
    loss.backward()
    return loss

# %%
for i in range(1000):
    loss = optimizer.step(closure)
    print(loss)
#     pointer_loss, task1_loss, task2_loss = optimizer.step(closure)
#     pointer_loss, task1_loss, task2_loss = closure()
#     print(float(pointer_loss)+float(task1_loss)+float(task2_loss))
#     print('ptr', float(pointer_loss))
#     print('task1', float(task1_loss))
#     print('task2', float(task2_loss))
# Out:
# tensor(-0.3817, grad_fn=<ThAddBackward>)
# tensor(-0.3827, grad_fn=<ThAddBackward>)
# tensor(-0.3837, grad_fn=<ThAddBackward>)
# tensor(-0.3846, grad_fn=<ThAddBackward>)
# tensor(-0.3856, grad_fn=<ThAddBackward>)
# tensor(-0.3866, grad_fn=<ThAddBackward>)
# tensor(-0.3876, grad_fn=<ThAddBackward>)
# tensor(-0.3887, grad_fn=<ThAddBackward>)
# tensor(-0.3897, grad_fn=<ThAddBackward>)
# tensor(-0.3908, grad_fn=<ThAddBackward>)
# tensor(-0.3919, grad_fn=<ThAddBackward>)
# tensor(-0.3931, grad_fn=<ThAddBackward>)
# tensor(-0.3942, grad_fn=<ThAddBackward>)
# tensor(-0.3955, grad_fn=<ThAddBackward>)
# tensor(-0.3967, grad_fn=<ThAddBackward>)
# tensor(-0.3980, grad_fn=<ThAddBackward>)
# tensor(-0.3994, grad_fn=<ThAddBackward>)
# tensor(-0.4008, grad_fn=<ThAddBackward>)
# tensor(-0.4024, grad_fn=<ThAddBackward>)
# tensor(-0.4039, grad_fn=<ThAddBackward>)
# tensor(-0.4056, grad_fn=<ThAddBackward>)
# tensor(-0.4074, grad_fn=<ThAddBackward>)
# tensor(-0.4094, grad_fn=<ThAddBackward>)
# tensor(-0.4114, grad_fn=<ThAddBackward>)
# tensor(-0.4136, grad_fn=<ThAddBackward>)
# tensor(-0.4161, grad_fn=<ThAddBackward>)
# tensor(-0.4187, grad_fn=<ThAddBackward>)
# tensor(-0.4216, grad_fn=<ThAddBackward>)
# tensor(-0.4247, grad_fn=<ThAddBackward>)
# tensor(-0.4282, grad_fn=<ThAddBackward>)
# tensor(-0.4321, grad_fn=<ThAddBackward>)
# tensor(-0.4364, grad_fn=<ThAddBackward>)
# tensor(-0.4413, grad_fn=<ThAddBackward>)
# tensor(-0.4467, grad_fn=<ThAddBackward>)
# tensor(-0.4529, grad_fn=<ThAddBackward>)
# tensor(-0.4599, grad_fn=<ThAddBackward>)
# tensor(-0.4679, grad_fn=<ThAddBackward>)
# tensor(-0.4768, grad_fn=<ThAddBackward>)
# tensor(-0.4870, grad_fn=<ThAddBackward>)
# tensor(-0.4984, grad_fn=<ThAddBackward>)
# tensor(-0.5110, grad_fn=<ThAddBackward>)
# tensor(-0.5250, grad_fn=<ThAddBackward>)
# tensor(-0.5402, grad_fn=<ThAddBackward>)
# tensor(-0.5565, grad_fn=<ThAddBackward>)
# tensor(-0.5738, grad_fn=<ThAddBackward>)
# tensor(-0.5919, grad_fn=<ThAddBackward>)
# tensor(-0.6107, grad_fn=<ThAddBackward>)
# tensor(-0.6298, grad_fn=<ThAddBackward>)
# tensor(-0.6493, grad_fn=<ThAddBackward>)
# tensor(-0.6689, grad_fn=<ThAddBackward>)
# tensor(-0.6885, grad_fn=<ThAddBackward>)
# tensor(-0.7081, grad_fn=<ThAddBackward>)
# tensor(-0.7276, grad_fn=<ThAddBackward>)
# tensor(-0.7470, grad_fn=<ThAddBackward>)
# tensor(-0.7663, grad_fn=<ThAddBackward>)
# tensor(-0.7853, grad_fn=<ThAddBackward>)
# tensor(-0.8040, grad_fn=<ThAddBackward>)
# tensor(-0.8223, grad_fn=<ThAddBackward>)
# tensor(-0.8401, grad_fn=<ThAddBackward>)
# tensor(-0.8573, grad_fn=<ThAddBackward>)
# tensor(-0.8737, grad_fn=<ThAddBackward>)
# tensor(-0.8894, grad_fn=<ThAddBackward>)
# tensor(-0.9042, grad_fn=<ThAddBackward>)
# tensor(-0.9181, grad_fn=<ThAddBackward>)
# tensor(-0.9310, grad_fn=<ThAddBackward>)
# tensor(-0.9430, grad_fn=<ThAddBackward>)
# tensor(-0.9541, grad_fn=<ThAddBackward>)
# tensor(-0.9644, grad_fn=<ThAddBackward>)
# tensor(-0.9738, grad_fn=<ThAddBackward>)
# tensor(-0.9824, grad_fn=<ThAddBackward>)
# tensor(-0.9904, grad_fn=<ThAddBackward>)
# tensor(-0.9977, grad_fn=<ThAddBackward>)
# tensor(-1.0044, grad_fn=<ThAddBackward>)
# tensor(-1.0105, grad_fn=<ThAddBackward>)
# tensor(-1.0162, grad_fn=<ThAddBackward>)
# tensor(-1.0213, grad_fn=<ThAddBackward>)
# tensor(-1.0261, grad_fn=<ThAddBackward>)
# tensor(-1.0305, grad_fn=<ThAddBackward>)
# tensor(-1.0345, grad_fn=<ThAddBackward>)
# tensor(-1.0382, grad_fn=<ThAddBackward>)
# tensor(-1.0416, grad_fn=<ThAddBackward>)
# tensor(-1.0448, grad_fn=<ThAddBackward>)
# tensor(-1.0478, grad_fn=<ThAddBackward>)
# tensor(-1.0505, grad_fn=<ThAddBackward>)
# tensor(-1.0531, grad_fn=<ThAddBackward>)
# tensor(-1.0555, grad_fn=<ThAddBackward>)
# tensor(-1.0577, grad_fn=<ThAddBackward>)
# tensor(-1.0599, grad_fn=<ThAddBackward>)
# tensor(-1.0619, grad_fn=<ThAddBackward>)
# tensor(-1.0637, grad_fn=<ThAddBackward>)
# tensor(-1.0655, grad_fn=<ThAddBackward>)
# tensor(-1.0672, grad_fn=<ThAddBackward>)
# tensor(-1.0688, grad_fn=<ThAddBackward>)
# tensor(-1.0703, grad_fn=<ThAddBackward>)
# tensor(-1.0718, grad_fn=<ThAddBackward>)
# tensor(-1.0732, grad_fn=<ThAddBackward>)
# tensor(-1.0746, grad_fn=<ThAddBackward>)
# tensor(-1.0759, grad_fn=<ThAddBackward>)
# tensor(-1.0771, grad_fn=<ThAddBackward>)
# tensor(-1.0783, grad_fn=<ThAddBackward>)
# tensor(-1.0795, grad_fn=<ThAddBackward>)
# tensor(-1.0806, grad_fn=<ThAddBackward>)
# tensor(-1.0817, grad_fn=<ThAddBackward>)
# tensor(-1.0828, grad_fn=<ThAddBackward>)
# tensor(-1.0839, grad_fn=<ThAddBackward>)
# tensor(-1.0849, grad_fn=<ThAddBackward>)
# tensor(-1.0859, grad_fn=<ThAddBackward>)
# tensor(-1.0868, grad_fn=<ThAddBackward>)
# tensor(-1.0878, grad_fn=<ThAddBackward>)
# tensor(-1.0887, grad_fn=<ThAddBackward>)
# tensor(-1.0897, grad_fn=<ThAddBackward>)
# tensor(-1.0906, grad_fn=<ThAddBackward>)
# tensor(-1.0915, grad_fn=<ThAddBackward>)
# tensor(-1.0924, grad_fn=<ThAddBackward>)
# tensor(-1.0932, grad_fn=<ThAddBackward>)
# tensor(-1.0941, grad_fn=<ThAddBackward>)
# tensor(-1.0950, grad_fn=<ThAddBackward>)
# tensor(-1.0958, grad_fn=<ThAddBackward>)
# tensor(-1.0966, grad_fn=<ThAddBackward>)
# tensor(-1.0975, grad_fn=<ThAddBackward>)
# tensor(-1.0983, grad_fn=<ThAddBackward>)
# tensor(-1.0991, grad_fn=<ThAddBackward>)
# tensor(-1.0999, grad_fn=<ThAddBackward>)
# tensor(-1.1007, grad_fn=<ThAddBackward>)
# tensor(-1.1015, grad_fn=<ThAddBackward>)
# tensor(-1.1023, grad_fn=<ThAddBackward>)
# tensor(-1.1031, grad_fn=<ThAddBackward>)
# tensor(-1.1039, grad_fn=<ThAddBackward>)
# tensor(-1.1046, grad_fn=<ThAddBackward>)
# tensor(-1.1054, grad_fn=<ThAddBackward>)
# tensor(-1.1062, grad_fn=<ThAddBackward>)
# tensor(-1.1070, grad_fn=<ThAddBackward>)
# tensor(-1.1077, grad_fn=<ThAddBackward>)
# tensor(-1.1085, grad_fn=<ThAddBackward>)
# tensor(-1.1093, grad_fn=<ThAddBackward>)
# tensor(-1.1100, grad_fn=<ThAddBackward>)
# tensor(-1.1108, grad_fn=<ThAddBackward>)
# tensor(-1.1115, grad_fn=<ThAddBackward>)
# tensor(-1.1123, grad_fn=<ThAddBackward>)
# tensor(-1.1130, grad_fn=<ThAddBackward>)
# tensor(-1.1138, grad_fn=<ThAddBackward>)
# tensor(-1.1145, grad_fn=<ThAddBackward>)
# tensor(-1.1153, grad_fn=<ThAddBackward>)
# tensor(-1.1160, grad_fn=<ThAddBackward>)
# tensor(-1.1167, grad_fn=<ThAddBackward>)
# tensor(-1.1175, grad_fn=<ThAddBackward>)
# tensor(-1.1182, grad_fn=<ThAddBackward>)
# tensor(-1.1189, grad_fn=<ThAddBackward>)
# tensor(-1.1197, grad_fn=<ThAddBackward>)
# tensor(-1.1204, grad_fn=<ThAddBackward>)
# tensor(-1.1211, grad_fn=<ThAddBackward>)
# tensor(-1.1218, grad_fn=<ThAddBackward>)
# tensor(-1.1225, grad_fn=<ThAddBackward>)
# tensor(-1.1233, grad_fn=<ThAddBackward>)
# tensor(-1.1240, grad_fn=<ThAddBackward>)
# tensor(-1.1247, grad_fn=<ThAddBackward>)
# tensor(-1.1254, grad_fn=<ThAddBackward>)
# tensor(-1.1261, grad_fn=<ThAddBackward>)
# tensor(-1.1268, grad_fn=<ThAddBackward>)
# tensor(-1.1275, grad_fn=<ThAddBackward>)
# tensor(-1.1282, grad_fn=<ThAddBackward>)
# tensor(-1.1290, grad_fn=<ThAddBackward>)
# tensor(-1.1297, grad_fn=<ThAddBackward>)
# tensor(-1.1304, grad_fn=<ThAddBackward>)
# tensor(-1.1311, grad_fn=<ThAddBackward>)
# tensor(-1.1318, grad_fn=<ThAddBackward>)
# tensor(-1.1325, grad_fn=<ThAddBackward>)
# tensor(-1.1332, grad_fn=<ThAddBackward>)
# tensor(-1.1340, grad_fn=<ThAddBackward>)
# tensor(-1.1347, grad_fn=<ThAddBackward>)
# tensor(-1.1354, grad_fn=<ThAddBackward>)
# tensor(-1.1361, grad_fn=<ThAddBackward>)
# tensor(-1.1368, grad_fn=<ThAddBackward>)
# tensor(-1.1376, grad_fn=<ThAddBackward>)
# tensor(-1.1383, grad_fn=<ThAddBackward>)
# tensor(-1.1390, grad_fn=<ThAddBackward>)
# tensor(-1.1398, grad_fn=<ThAddBackward>)
# tensor(-1.1405, grad_fn=<ThAddBackward>)
# tensor(-1.1412, grad_fn=<ThAddBackward>)
# tensor(-1.1420, grad_fn=<ThAddBackward>)
# tensor(-1.1427, grad_fn=<ThAddBackward>)
# tensor(-1.1434, grad_fn=<ThAddBackward>)
# tensor(-1.1442, grad_fn=<ThAddBackward>)
# tensor(-1.1449, grad_fn=<ThAddBackward>)
# tensor(-1.1457, grad_fn=<ThAddBackward>)
# tensor(-1.1464, grad_fn=<ThAddBackward>)
# tensor(-1.1472, grad_fn=<ThAddBackward>)
# tensor(-1.1479, grad_fn=<ThAddBackward>)
# tensor(-1.1487, grad_fn=<ThAddBackward>)
# tensor(-1.1494, grad_fn=<ThAddBackward>)
# tensor(-1.1502, grad_fn=<ThAddBackward>)
# tensor(-1.1509, grad_fn=<ThAddBackward>)
# tensor(-1.1516, grad_fn=<ThAddBackward>)
# tensor(-1.1524, grad_fn=<ThAddBackward>)
# tensor(-1.1531, grad_fn=<ThAddBackward>)
# tensor(-1.1539, grad_fn=<ThAddBackward>)
# tensor(-1.1546, grad_fn=<ThAddBackward>)
# tensor(-1.1553, grad_fn=<ThAddBackward>)
# tensor(-1.1560, grad_fn=<ThAddBackward>)
# tensor(-1.1568, grad_fn=<ThAddBackward>)
# tensor(-1.1575, grad_fn=<ThAddBackward>)
# tensor(-1.1582, grad_fn=<ThAddBackward>)
# tensor(-1.1589, grad_fn=<ThAddBackward>)
# tensor(-1.1597, grad_fn=<ThAddBackward>)
# tensor(-1.1604, grad_fn=<ThAddBackward>)
# tensor(-1.1611, grad_fn=<ThAddBackward>)
# tensor(-1.1618, grad_fn=<ThAddBackward>)
# tensor(-1.1626, grad_fn=<ThAddBackward>)
# tensor(-1.1633, grad_fn=<ThAddBackward>)
# tensor(-1.1640, grad_fn=<ThAddBackward>)
# tensor(-1.1647, grad_fn=<ThAddBackward>)
# tensor(-1.1654, grad_fn=<ThAddBackward>)
# tensor(-1.1662, grad_fn=<ThAddBackward>)
# tensor(-1.1669, grad_fn=<ThAddBackward>)
# tensor(-1.1676, grad_fn=<ThAddBackward>)
# tensor(-1.1683, grad_fn=<ThAddBackward>)
# tensor(-1.1690, grad_fn=<ThAddBackward>)
# tensor(-1.1697, grad_fn=<ThAddBackward>)
# tensor(-1.1704, grad_fn=<ThAddBackward>)
# tensor(-1.1711, grad_fn=<ThAddBackward>)
# tensor(-1.1718, grad_fn=<ThAddBackward>)
# tensor(-1.1725, grad_fn=<ThAddBackward>)
# tensor(-1.1732, grad_fn=<ThAddBackward>)
# tensor(-1.1739, grad_fn=<ThAddBackward>)
# tensor(-1.1746, grad_fn=<ThAddBackward>)
# tensor(-1.1753, grad_fn=<ThAddBackward>)
# tensor(-1.1760, grad_fn=<ThAddBackward>)
# tensor(-1.1767, grad_fn=<ThAddBackward>)
# tensor(-1.1774, grad_fn=<ThAddBackward>)
# tensor(-1.1781, grad_fn=<ThAddBackward>)
# tensor(-1.1788, grad_fn=<ThAddBackward>)
# tensor(-1.1795, grad_fn=<ThAddBackward>)
# tensor(-1.1802, grad_fn=<ThAddBackward>)
# tensor(-1.1809, grad_fn=<ThAddBackward>)
# tensor(-1.1816, grad_fn=<ThAddBackward>)
# tensor(-1.1823, grad_fn=<ThAddBackward>)
# tensor(-1.1830, grad_fn=<ThAddBackward>)
# tensor(-1.1837, grad_fn=<ThAddBackward>)
# tensor(-1.1844, grad_fn=<ThAddBackward>)
# tensor(-1.1851, grad_fn=<ThAddBackward>)
# tensor(-1.1858, grad_fn=<ThAddBackward>)
# tensor(-1.1865, grad_fn=<ThAddBackward>)
# tensor(-1.1872, grad_fn=<ThAddBackward>)
# tensor(-1.1879, grad_fn=<ThAddBackward>)
# tensor(-1.1886, grad_fn=<ThAddBackward>)
# tensor(-1.1893, grad_fn=<ThAddBackward>)
# tensor(-1.1900, grad_fn=<ThAddBackward>)
# tensor(-1.1908, grad_fn=<ThAddBackward>)
# tensor(-1.1915, grad_fn=<ThAddBackward>)
# tensor(-1.1922, grad_fn=<ThAddBackward>)
# tensor(-1.1929, grad_fn=<ThAddBackward>)
# tensor(-1.1936, grad_fn=<ThAddBackward>)
# tensor(-1.1943, grad_fn=<ThAddBackward>)
# tensor(-1.1950, grad_fn=<ThAddBackward>)
# tensor(-1.1958, grad_fn=<ThAddBackward>)
# tensor(-1.1965, grad_fn=<ThAddBackward>)
# tensor(-1.1972, grad_fn=<ThAddBackward>)
# tensor(-1.1979, grad_fn=<ThAddBackward>)
# tensor(-1.1987, grad_fn=<ThAddBackward>)
# tensor(-1.1994, grad_fn=<ThAddBackward>)
# tensor(-1.2001, grad_fn=<ThAddBackward>)
# tensor(-1.2009, grad_fn=<ThAddBackward>)
# tensor(-1.2016, grad_fn=<ThAddBackward>)
# tensor(-1.2023, grad_fn=<ThAddBackward>)
# tensor(-1.2031, grad_fn=<ThAddBackward>)
# tensor(-1.2038, grad_fn=<ThAddBackward>)
# tensor(-1.2046, grad_fn=<ThAddBackward>)
# tensor(-1.2053, grad_fn=<ThAddBackward>)
# tensor(-1.2061, grad_fn=<ThAddBackward>)
# tensor(-1.2069, grad_fn=<ThAddBackward>)
# tensor(-1.2076, grad_fn=<ThAddBackward>)
# tensor(-1.2084, grad_fn=<ThAddBackward>)
# tensor(-1.2092, grad_fn=<ThAddBackward>)
# tensor(-1.2099, grad_fn=<ThAddBackward>)
# tensor(-1.2107, grad_fn=<ThAddBackward>)
# tensor(-1.2115, grad_fn=<ThAddBackward>)
# tensor(-1.2123, grad_fn=<ThAddBackward>)
# tensor(-1.2131, grad_fn=<ThAddBackward>)
# tensor(-1.2139, grad_fn=<ThAddBackward>)
# tensor(-1.2147, grad_fn=<ThAddBackward>)
# tensor(-1.2155, grad_fn=<ThAddBackward>)
# tensor(-1.2163, grad_fn=<ThAddBackward>)
# tensor(-1.2172, grad_fn=<ThAddBackward>)
# tensor(-1.2180, grad_fn=<ThAddBackward>)
# tensor(-1.2188, grad_fn=<ThAddBackward>)
# tensor(-1.2197, grad_fn=<ThAddBackward>)
# tensor(-1.2205, grad_fn=<ThAddBackward>)
# tensor(-1.2214, grad_fn=<ThAddBackward>)
# tensor(-1.2222, grad_fn=<ThAddBackward>)
# tensor(-1.2231, grad_fn=<ThAddBackward>)
# tensor(-1.2239, grad_fn=<ThAddBackward>)
# tensor(-1.2248, grad_fn=<ThAddBackward>)
# tensor(-1.2257, grad_fn=<ThAddBackward>)
# tensor(-1.2266, grad_fn=<ThAddBackward>)
# tensor(-1.2275, grad_fn=<ThAddBackward>)
# tensor(-1.2284, grad_fn=<ThAddBackward>)
# tensor(-1.2293, grad_fn=<ThAddBackward>)
# tensor(-1.2302, grad_fn=<ThAddBackward>)
# tensor(-1.2311, grad_fn=<ThAddBackward>)
# tensor(-1.2321, grad_fn=<ThAddBackward>)
# tensor(-1.2330, grad_fn=<ThAddBackward>)
# tensor(-1.2340, grad_fn=<ThAddBackward>)
# tensor(-1.2349, grad_fn=<ThAddBackward>)
# tensor(-1.2359, grad_fn=<ThAddBackward>)
# tensor(-1.2369, grad_fn=<ThAddBackward>)
# tensor(-1.2378, grad_fn=<ThAddBackward>)
# tensor(-1.2388, grad_fn=<ThAddBackward>)
# tensor(-1.2398, grad_fn=<ThAddBackward>)
# tensor(-1.2408, grad_fn=<ThAddBackward>)
# tensor(-1.2418, grad_fn=<ThAddBackward>)
# tensor(-1.2429, grad_fn=<ThAddBackward>)
# tensor(-1.2439, grad_fn=<ThAddBackward>)
# tensor(-1.2450, grad_fn=<ThAddBackward>)
# tensor(-1.2460, grad_fn=<ThAddBackward>)
# tensor(-1.2471, grad_fn=<ThAddBackward>)
# tensor(-1.2482, grad_fn=<ThAddBackward>)
# tensor(-1.2492, grad_fn=<ThAddBackward>)
# tensor(-1.2503, grad_fn=<ThAddBackward>)
# tensor(-1.2514, grad_fn=<ThAddBackward>)
# tensor(-1.2526, grad_fn=<ThAddBackward>)
# tensor(-1.2537, grad_fn=<ThAddBackward>)
# tensor(-1.2548, grad_fn=<ThAddBackward>)
# tensor(-1.2560, grad_fn=<ThAddBackward>)
# tensor(-1.2571, grad_fn=<ThAddBackward>)
# tensor(-1.2583, grad_fn=<ThAddBackward>)
# tensor(-1.2595, grad_fn=<ThAddBackward>)
# tensor(-1.2607, grad_fn=<ThAddBackward>)
# tensor(-1.2619, grad_fn=<ThAddBackward>)
# tensor(-1.2631, grad_fn=<ThAddBackward>)
# tensor(-1.2643, grad_fn=<ThAddBackward>)
# tensor(-1.2656, grad_fn=<ThAddBackward>)
# tensor(-1.2668, grad_fn=<ThAddBackward>)
# tensor(-1.2681, grad_fn=<ThAddBackward>)
# tensor(-1.2693, grad_fn=<ThAddBackward>)
# tensor(-1.2706, grad_fn=<ThAddBackward>)
# tensor(-1.2719, grad_fn=<ThAddBackward>)
# tensor(-1.2732, grad_fn=<ThAddBackward>)
# tensor(-1.2746, grad_fn=<ThAddBackward>)
# tensor(-1.2759, grad_fn=<ThAddBackward>)
# tensor(-1.2772, grad_fn=<ThAddBackward>)
# tensor(-1.2786, grad_fn=<ThAddBackward>)
# tensor(-1.2799, grad_fn=<ThAddBackward>)
# tensor(-1.2813, grad_fn=<ThAddBackward>)
# tensor(-1.2827, grad_fn=<ThAddBackward>)
# tensor(-1.2841, grad_fn=<ThAddBackward>)
# tensor(-1.2855, grad_fn=<ThAddBackward>)
# tensor(-1.2870, grad_fn=<ThAddBackward>)
# tensor(-1.2884, grad_fn=<ThAddBackward>)
# tensor(-1.2898, grad_fn=<ThAddBackward>)
# tensor(-1.2913, grad_fn=<ThAddBackward>)
# tensor(-1.2928, grad_fn=<ThAddBackward>)
# tensor(-1.2942, grad_fn=<ThAddBackward>)
# tensor(-1.2957, grad_fn=<ThAddBackward>)
# tensor(-1.2972, grad_fn=<ThAddBackward>)
# tensor(-1.2987, grad_fn=<ThAddBackward>)
# tensor(-1.3002, grad_fn=<ThAddBackward>)
# tensor(-1.3017, grad_fn=<ThAddBackward>)
# tensor(-1.3033, grad_fn=<ThAddBackward>)
# tensor(-1.3048, grad_fn=<ThAddBackward>)
# tensor(-1.3063, grad_fn=<ThAddBackward>)
# tensor(-1.3079, grad_fn=<ThAddBackward>)
# tensor(-1.3094, grad_fn=<ThAddBackward>)
# tensor(-1.3110, grad_fn=<ThAddBackward>)
# tensor(-1.3126, grad_fn=<ThAddBackward>)
# tensor(-1.3141, grad_fn=<ThAddBackward>)
# tensor(-1.3157, grad_fn=<ThAddBackward>)
# tensor(-1.3172, grad_fn=<ThAddBackward>)
# tensor(-1.3188, grad_fn=<ThAddBackward>)
# tensor(-1.3204, grad_fn=<ThAddBackward>)
# tensor(-1.3220, grad_fn=<ThAddBackward>)
# tensor(-1.3236, grad_fn=<ThAddBackward>)
# tensor(-1.3251, grad_fn=<ThAddBackward>)
# tensor(-1.3267, grad_fn=<ThAddBackward>)
# tensor(-1.3283, grad_fn=<ThAddBackward>)
# tensor(-1.3299, grad_fn=<ThAddBackward>)
# tensor(-1.3316, grad_fn=<ThAddBackward>)
# tensor(-1.3332, grad_fn=<ThAddBackward>)
# tensor(-1.3348, grad_fn=<ThAddBackward>)
# tensor(-1.3365, grad_fn=<ThAddBackward>)
# tensor(-1.3382, grad_fn=<ThAddBackward>)
# tensor(-1.3399, grad_fn=<ThAddBackward>)
# tensor(-1.3417, grad_fn=<ThAddBackward>)
# tensor(-1.3435, grad_fn=<ThAddBackward>)
# tensor(-1.3453, grad_fn=<ThAddBackward>)
# tensor(-1.3473, grad_fn=<ThAddBackward>)
# tensor(-1.3493, grad_fn=<ThAddBackward>)
# tensor(-1.3515, grad_fn=<ThAddBackward>)
# tensor(-1.3538, grad_fn=<ThAddBackward>)
# tensor(-1.3562, grad_fn=<ThAddBackward>)
# tensor(-1.3588, grad_fn=<ThAddBackward>)
# tensor(-1.3614, grad_fn=<ThAddBackward>)
# tensor(-1.3640, grad_fn=<ThAddBackward>)
# tensor(-1.3666, grad_fn=<ThAddBackward>)
# tensor(-1.3689, grad_fn=<ThAddBackward>)
# tensor(-1.3712, grad_fn=<ThAddBackward>)
# tensor(-1.3734, grad_fn=<ThAddBackward>)
# tensor(-1.3757, grad_fn=<ThAddBackward>)
# tensor(-1.3780, grad_fn=<ThAddBackward>)
# tensor(-1.3804, grad_fn=<ThAddBackward>)
# tensor(-1.3828, grad_fn=<ThAddBackward>)
# tensor(-1.3851, grad_fn=<ThAddBackward>)
# tensor(-1.3875, grad_fn=<ThAddBackward>)
# tensor(-1.3898, grad_fn=<ThAddBackward>)
# tensor(-1.3920, grad_fn=<ThAddBackward>)
# tensor(-1.3942, grad_fn=<ThAddBackward>)
# tensor(-1.3964, grad_fn=<ThAddBackward>)
# tensor(-1.3986, grad_fn=<ThAddBackward>)
# tensor(-1.4007, grad_fn=<ThAddBackward>)
# tensor(-1.4029, grad_fn=<ThAddBackward>)
# tensor(-1.4050, grad_fn=<ThAddBackward>)
# tensor(-1.4072, grad_fn=<ThAddBackward>)
# tensor(-1.4092, grad_fn=<ThAddBackward>)
# tensor(-1.4113, grad_fn=<ThAddBackward>)
# tensor(-1.4134, grad_fn=<ThAddBackward>)
# tensor(-1.4155, grad_fn=<ThAddBackward>)
# tensor(-1.4176, grad_fn=<ThAddBackward>)
# tensor(-1.4198, grad_fn=<ThAddBackward>)
# tensor(-1.4220, grad_fn=<ThAddBackward>)
# tensor(-1.4242, grad_fn=<ThAddBackward>)
# tensor(-1.4265, grad_fn=<ThAddBackward>)
# tensor(-1.4289, grad_fn=<ThAddBackward>)
# tensor(-1.4313, grad_fn=<ThAddBackward>)
# tensor(-1.4337, grad_fn=<ThAddBackward>)
# tensor(-1.4362, grad_fn=<ThAddBackward>)
# tensor(-1.4388, grad_fn=<ThAddBackward>)
# tensor(-1.4414, grad_fn=<ThAddBackward>)
# tensor(-1.4440, grad_fn=<ThAddBackward>)
# tensor(-1.4466, grad_fn=<ThAddBackward>)
# tensor(-1.4492, grad_fn=<ThAddBackward>)
# tensor(-1.4518, grad_fn=<ThAddBackward>)
# tensor(-1.4544, grad_fn=<ThAddBackward>)
# tensor(-1.4569, grad_fn=<ThAddBackward>)
# tensor(-1.4594, grad_fn=<ThAddBackward>)
# tensor(-1.4619, grad_fn=<ThAddBackward>)
# tensor(-1.4643, grad_fn=<ThAddBackward>)
# tensor(-1.4668, grad_fn=<ThAddBackward>)
# tensor(-1.4692, grad_fn=<ThAddBackward>)
# tensor(-1.4715, grad_fn=<ThAddBackward>)
# tensor(-1.4739, grad_fn=<ThAddBackward>)
# tensor(-1.4762, grad_fn=<ThAddBackward>)
# tensor(-1.4785, grad_fn=<ThAddBackward>)
# tensor(-1.4808, grad_fn=<ThAddBackward>)
# tensor(-1.4830, grad_fn=<ThAddBackward>)
# tensor(-1.4853, grad_fn=<ThAddBackward>)
# tensor(-1.4874, grad_fn=<ThAddBackward>)
# tensor(-1.4896, grad_fn=<ThAddBackward>)
# tensor(-1.4917, grad_fn=<ThAddBackward>)
# tensor(-1.4938, grad_fn=<ThAddBackward>)
# tensor(-1.4958, grad_fn=<ThAddBackward>)
# tensor(-1.4978, grad_fn=<ThAddBackward>)
# tensor(-1.4998, grad_fn=<ThAddBackward>)
# tensor(-1.5017, grad_fn=<ThAddBackward>)
# tensor(-1.5036, grad_fn=<ThAddBackward>)
# tensor(-1.5055, grad_fn=<ThAddBackward>)
# tensor(-1.5073, grad_fn=<ThAddBackward>)
# tensor(-1.5091, grad_fn=<ThAddBackward>)
# tensor(-1.5109, grad_fn=<ThAddBackward>)
# tensor(-1.5127, grad_fn=<ThAddBackward>)
# tensor(-1.5144, grad_fn=<ThAddBackward>)
# tensor(-1.5162, grad_fn=<ThAddBackward>)
# tensor(-1.5179, grad_fn=<ThAddBackward>)
# tensor(-1.5196, grad_fn=<ThAddBackward>)
# tensor(-1.5213, grad_fn=<ThAddBackward>)
# tensor(-1.5229, grad_fn=<ThAddBackward>)
# tensor(-1.5245, grad_fn=<ThAddBackward>)
# tensor(-1.5261, grad_fn=<ThAddBackward>)
# tensor(-1.5276, grad_fn=<ThAddBackward>)
# tensor(-1.5291, grad_fn=<ThAddBackward>)
# tensor(-1.5305, grad_fn=<ThAddBackward>)
# tensor(-1.5319, grad_fn=<ThAddBackward>)
# tensor(-1.5333, grad_fn=<ThAddBackward>)
# tensor(-1.5346, grad_fn=<ThAddBackward>)
# tensor(-1.5360, grad_fn=<ThAddBackward>)
# tensor(-1.5373, grad_fn=<ThAddBackward>)
# tensor(-1.5385, grad_fn=<ThAddBackward>)
# tensor(-1.5398, grad_fn=<ThAddBackward>)
# tensor(-1.5410, grad_fn=<ThAddBackward>)
# tensor(-1.5422, grad_fn=<ThAddBackward>)
# tensor(-1.5434, grad_fn=<ThAddBackward>)
# tensor(-1.5446, grad_fn=<ThAddBackward>)
# tensor(-1.5457, grad_fn=<ThAddBackward>)
# tensor(-1.5469, grad_fn=<ThAddBackward>)
# tensor(-1.5480, grad_fn=<ThAddBackward>)
# tensor(-1.5491, grad_fn=<ThAddBackward>)
# tensor(-1.5502, grad_fn=<ThAddBackward>)
# tensor(-1.5513, grad_fn=<ThAddBackward>)
# tensor(-1.5524, grad_fn=<ThAddBackward>)
# tensor(-1.5535, grad_fn=<ThAddBackward>)
# tensor(-1.5546, grad_fn=<ThAddBackward>)
# tensor(-1.5557, grad_fn=<ThAddBackward>)
# tensor(-1.5567, grad_fn=<ThAddBackward>)
# tensor(-1.5578, grad_fn=<ThAddBackward>)
# tensor(-1.5588, grad_fn=<ThAddBackward>)
# tensor(-1.5599, grad_fn=<ThAddBackward>)
# tensor(-1.5609, grad_fn=<ThAddBackward>)
# tensor(-1.5619, grad_fn=<ThAddBackward>)
# tensor(-1.5629, grad_fn=<ThAddBackward>)
# tensor(-1.5639, grad_fn=<ThAddBackward>)
# tensor(-1.5649, grad_fn=<ThAddBackward>)
# tensor(-1.5658, grad_fn=<ThAddBackward>)
# tensor(-1.5668, grad_fn=<ThAddBackward>)
# tensor(-1.5676, grad_fn=<ThAddBackward>)
# tensor(-1.5685, grad_fn=<ThAddBackward>)
# tensor(-1.5694, grad_fn=<ThAddBackward>)
# tensor(-1.5702, grad_fn=<ThAddBackward>)
# tensor(-1.5710, grad_fn=<ThAddBackward>)
# tensor(-1.5718, grad_fn=<ThAddBackward>)
# tensor(-1.5725, grad_fn=<ThAddBackward>)
# tensor(-1.5732, grad_fn=<ThAddBackward>)
# tensor(-1.5740, grad_fn=<ThAddBackward>)
# tensor(-1.5746, grad_fn=<ThAddBackward>)
# tensor(-1.5753, grad_fn=<ThAddBackward>)
# tensor(-1.5760, grad_fn=<ThAddBackward>)
# tensor(-1.5767, grad_fn=<ThAddBackward>)
# tensor(-1.5773, grad_fn=<ThAddBackward>)
# tensor(-1.5779, grad_fn=<ThAddBackward>)
# tensor(-1.5786, grad_fn=<ThAddBackward>)
# tensor(-1.5792, grad_fn=<ThAddBackward>)
# tensor(-1.5798, grad_fn=<ThAddBackward>)
# tensor(-1.5804, grad_fn=<ThAddBackward>)
# tensor(-1.5810, grad_fn=<ThAddBackward>)
# tensor(-1.5816, grad_fn=<ThAddBackward>)
# tensor(-1.5822, grad_fn=<ThAddBackward>)
# tensor(-1.5827, grad_fn=<ThAddBackward>)
# tensor(-1.5833, grad_fn=<ThAddBackward>)
# tensor(-1.5839, grad_fn=<ThAddBackward>)
# tensor(-1.5844, grad_fn=<ThAddBackward>)
# tensor(-1.5850, grad_fn=<ThAddBackward>)
# tensor(-1.5855, grad_fn=<ThAddBackward>)
# tensor(-1.5861, grad_fn=<ThAddBackward>)
# tensor(-1.5866, grad_fn=<ThAddBackward>)
# tensor(-1.5871, grad_fn=<ThAddBackward>)
# tensor(-1.5876, grad_fn=<ThAddBackward>)
# tensor(-1.5881, grad_fn=<ThAddBackward>)
# tensor(-1.5886, grad_fn=<ThAddBackward>)
# tensor(-1.5891, grad_fn=<ThAddBackward>)
# tensor(-1.5896, grad_fn=<ThAddBackward>)
# tensor(-1.5901, grad_fn=<ThAddBackward>)
# tensor(-1.5906, grad_fn=<ThAddBackward>)
# tensor(-1.5910, grad_fn=<ThAddBackward>)
# tensor(-1.5915, grad_fn=<ThAddBackward>)
# tensor(-1.5920, grad_fn=<ThAddBackward>)
# tensor(-1.5924, grad_fn=<ThAddBackward>)
# tensor(-1.5929, grad_fn=<ThAddBackward>)
# tensor(-1.5933, grad_fn=<ThAddBackward>)
# tensor(-1.5938, grad_fn=<ThAddBackward>)
# tensor(-1.5942, grad_fn=<ThAddBackward>)
# tensor(-1.5946, grad_fn=<ThAddBackward>)
# tensor(-1.5950, grad_fn=<ThAddBackward>)
# tensor(-1.5955, grad_fn=<ThAddBackward>)
# tensor(-1.5959, grad_fn=<ThAddBackward>)
# tensor(-1.5963, grad_fn=<ThAddBackward>)
# tensor(-1.5967, grad_fn=<ThAddBackward>)
# tensor(-1.5971, grad_fn=<ThAddBackward>)
# tensor(-1.5975, grad_fn=<ThAddBackward>)
# tensor(-1.5979, grad_fn=<ThAddBackward>)
# tensor(-1.5982, grad_fn=<ThAddBackward>)
# tensor(-1.5986, grad_fn=<ThAddBackward>)
# tensor(-1.5990, grad_fn=<ThAddBackward>)
# tensor(-1.5994, grad_fn=<ThAddBackward>)
# tensor(-1.5997, grad_fn=<ThAddBackward>)
# tensor(-1.6001, grad_fn=<ThAddBackward>)
# tensor(-1.6005, grad_fn=<ThAddBackward>)
# tensor(-1.6008, grad_fn=<ThAddBackward>)
# tensor(-1.6012, grad_fn=<ThAddBackward>)
# tensor(-1.6015, grad_fn=<ThAddBackward>)
# tensor(-1.6019, grad_fn=<ThAddBackward>)
# tensor(-1.6022, grad_fn=<ThAddBackward>)
# tensor(-1.6025, grad_fn=<ThAddBackward>)
# tensor(-1.6029, grad_fn=<ThAddBackward>)
# tensor(-1.6032, grad_fn=<ThAddBackward>)
# tensor(-1.6035, grad_fn=<ThAddBackward>)
# tensor(-1.6038, grad_fn=<ThAddBackward>)
# tensor(-1.6042, grad_fn=<ThAddBackward>)
# tensor(-1.6045, grad_fn=<ThAddBackward>)
# tensor(-1.6048, grad_fn=<ThAddBackward>)
# tensor(-1.6051, grad_fn=<ThAddBackward>)
# tensor(-1.6054, grad_fn=<ThAddBackward>)
# tensor(-1.6057, grad_fn=<ThAddBackward>)
# tensor(-1.6060, grad_fn=<ThAddBackward>)
# tensor(-1.6063, grad_fn=<ThAddBackward>)
# tensor(-1.6066, grad_fn=<ThAddBackward>)
# tensor(-1.6069, grad_fn=<ThAddBackward>)
# tensor(-1.6071, grad_fn=<ThAddBackward>)
# tensor(-1.6074, grad_fn=<ThAddBackward>)
# tensor(-1.6077, grad_fn=<ThAddBackward>)
# tensor(-1.6080, grad_fn=<ThAddBackward>)
# tensor(-1.6083, grad_fn=<ThAddBackward>)
# tensor(-1.6085, grad_fn=<ThAddBackward>)
# tensor(-1.6088, grad_fn=<ThAddBackward>)
# tensor(-1.6091, grad_fn=<ThAddBackward>)
# tensor(-1.6093, grad_fn=<ThAddBackward>)
# tensor(-1.6096, grad_fn=<ThAddBackward>)
# tensor(-1.6098, grad_fn=<ThAddBackward>)
# tensor(-1.6101, grad_fn=<ThAddBackward>)
# tensor(-1.6103, grad_fn=<ThAddBackward>)
# tensor(-1.6106, grad_fn=<ThAddBackward>)
# tensor(-1.6108, grad_fn=<ThAddBackward>)
# tensor(-1.6111, grad_fn=<ThAddBackward>)
# tensor(-1.6113, grad_fn=<ThAddBackward>)
# tensor(-1.6115, grad_fn=<ThAddBackward>)
# tensor(-1.6118, grad_fn=<ThAddBackward>)
# tensor(-1.6120, grad_fn=<ThAddBackward>)
# tensor(-1.6122, grad_fn=<ThAddBackward>)
# tensor(-1.6125, grad_fn=<ThAddBackward>)
# tensor(-1.6127, grad_fn=<ThAddBackward>)
# tensor(-1.6129, grad_fn=<ThAddBackward>)
# tensor(-1.6132, grad_fn=<ThAddBackward>)
# tensor(-1.6134, grad_fn=<ThAddBackward>)
# tensor(-1.6136, grad_fn=<ThAddBackward>)
# tensor(-1.6138, grad_fn=<ThAddBackward>)
# tensor(-1.6140, grad_fn=<ThAddBackward>)
# tensor(-1.6142, grad_fn=<ThAddBackward>)
# tensor(-1.6144, grad_fn=<ThAddBackward>)
# tensor(-1.6146, grad_fn=<ThAddBackward>)
# tensor(-1.6149, grad_fn=<ThAddBackward>)
# tensor(-1.6151, grad_fn=<ThAddBackward>)
# tensor(-1.6153, grad_fn=<ThAddBackward>)
# tensor(-1.6155, grad_fn=<ThAddBackward>)
# tensor(-1.6157, grad_fn=<ThAddBackward>)
# tensor(-1.6159, grad_fn=<ThAddBackward>)
# tensor(-1.6161, grad_fn=<ThAddBackward>)
# tensor(-1.6162, grad_fn=<ThAddBackward>)
# tensor(-1.6164, grad_fn=<ThAddBackward>)
# tensor(-1.6166, grad_fn=<ThAddBackward>)
# tensor(-1.6168, grad_fn=<ThAddBackward>)
# tensor(-1.6170, grad_fn=<ThAddBackward>)
# tensor(-1.6172, grad_fn=<ThAddBackward>)
# tensor(-1.6174, grad_fn=<ThAddBackward>)
# tensor(-1.6176, grad_fn=<ThAddBackward>)
# tensor(-1.6177, grad_fn=<ThAddBackward>)
# tensor(-1.6179, grad_fn=<ThAddBackward>)
# tensor(-1.6181, grad_fn=<ThAddBackward>)
# tensor(-1.6183, grad_fn=<ThAddBackward>)
# tensor(-1.6184, grad_fn=<ThAddBackward>)
# tensor(-1.6186, grad_fn=<ThAddBackward>)
# tensor(-1.6188, grad_fn=<ThAddBackward>)
# tensor(-1.6190, grad_fn=<ThAddBackward>)
# tensor(-1.6191, grad_fn=<ThAddBackward>)
# tensor(-1.6193, grad_fn=<ThAddBackward>)
# tensor(-1.6195, grad_fn=<ThAddBackward>)
# tensor(-1.6196, grad_fn=<ThAddBackward>)
# tensor(-1.6198, grad_fn=<ThAddBackward>)
# tensor(-1.6200, grad_fn=<ThAddBackward>)
# tensor(-1.6201, grad_fn=<ThAddBackward>)
# tensor(-1.6203, grad_fn=<ThAddBackward>)
# tensor(-1.6205, grad_fn=<ThAddBackward>)
# tensor(-1.6206, grad_fn=<ThAddBackward>)
# tensor(-1.6208, grad_fn=<ThAddBackward>)
# tensor(-1.6209, grad_fn=<ThAddBackward>)
# tensor(-1.6211, grad_fn=<ThAddBackward>)
# tensor(-1.6213, grad_fn=<ThAddBackward>)
# tensor(-1.6214, grad_fn=<ThAddBackward>)
# tensor(-1.6216, grad_fn=<ThAddBackward>)
# tensor(-1.6217, grad_fn=<ThAddBackward>)
# tensor(-1.6219, grad_fn=<ThAddBackward>)
# tensor(-1.6220, grad_fn=<ThAddBackward>)
# tensor(-1.6222, grad_fn=<ThAddBackward>)
# tensor(-1.6223, grad_fn=<ThAddBackward>)
# tensor(-1.6225, grad_fn=<ThAddBackward>)
# tensor(-1.6226, grad_fn=<ThAddBackward>)
# tensor(-1.6228, grad_fn=<ThAddBackward>)
# tensor(-1.6230, grad_fn=<ThAddBackward>)
# tensor(-1.6231, grad_fn=<ThAddBackward>)
# tensor(-1.6233, grad_fn=<ThAddBackward>)
# tensor(-1.6234, grad_fn=<ThAddBackward>)
# tensor(-1.6236, grad_fn=<ThAddBackward>)
# tensor(-1.6237, grad_fn=<ThAddBackward>)
# tensor(-1.6239, grad_fn=<ThAddBackward>)
# tensor(-1.6240, grad_fn=<ThAddBackward>)
# tensor(-1.6242, grad_fn=<ThAddBackward>)
# tensor(-1.6243, grad_fn=<ThAddBackward>)
# tensor(-1.6245, grad_fn=<ThAddBackward>)
# tensor(-1.6246, grad_fn=<ThAddBackward>)
# tensor(-1.6248, grad_fn=<ThAddBackward>)
# tensor(-1.6249, grad_fn=<ThAddBackward>)
# tensor(-1.6251, grad_fn=<ThAddBackward>)
# tensor(-1.6252, grad_fn=<ThAddBackward>)
# tensor(-1.6254, grad_fn=<ThAddBackward>)
# tensor(-1.6256, grad_fn=<ThAddBackward>)
# tensor(-1.6257, grad_fn=<ThAddBackward>)
# tensor(-1.6259, grad_fn=<ThAddBackward>)
# tensor(-1.6261, grad_fn=<ThAddBackward>)
# tensor(-1.6262, grad_fn=<ThAddBackward>)
# tensor(-1.6264, grad_fn=<ThAddBackward>)
# tensor(-1.6266, grad_fn=<ThAddBackward>)
# tensor(-1.6267, grad_fn=<ThAddBackward>)
# tensor(-1.6269, grad_fn=<ThAddBackward>)
# tensor(-1.6271, grad_fn=<ThAddBackward>)
# tensor(-1.6273, grad_fn=<ThAddBackward>)
# tensor(-1.6275, grad_fn=<ThAddBackward>)
# tensor(-1.6277, grad_fn=<ThAddBackward>)
# tensor(-1.6278, grad_fn=<ThAddBackward>)
# tensor(-1.6280, grad_fn=<ThAddBackward>)
# tensor(-1.6283, grad_fn=<ThAddBackward>)
# tensor(-1.6285, grad_fn=<ThAddBackward>)
# tensor(-1.6287, grad_fn=<ThAddBackward>)
# tensor(-1.6289, grad_fn=<ThAddBackward>)
# tensor(-1.6291, grad_fn=<ThAddBackward>)
# tensor(-1.6294, grad_fn=<ThAddBackward>)
# tensor(-1.6296, grad_fn=<ThAddBackward>)
# tensor(-1.6299, grad_fn=<ThAddBackward>)
# tensor(-1.6302, grad_fn=<ThAddBackward>)
# tensor(-1.6305, grad_fn=<ThAddBackward>)
# tensor(-1.6308, grad_fn=<ThAddBackward>)
# tensor(-1.6311, grad_fn=<ThAddBackward>)
# tensor(-1.6314, grad_fn=<ThAddBackward>)
# tensor(-1.6317, grad_fn=<ThAddBackward>)
# tensor(-1.6321, grad_fn=<ThAddBackward>)
# tensor(-1.6324, grad_fn=<ThAddBackward>)
# tensor(-1.6328, grad_fn=<ThAddBackward>)
# tensor(-1.6333, grad_fn=<ThAddBackward>)
# tensor(-1.6337, grad_fn=<ThAddBackward>)
# tensor(-1.6342, grad_fn=<ThAddBackward>)
# tensor(-1.6347, grad_fn=<ThAddBackward>)
# tensor(-1.6352, grad_fn=<ThAddBackward>)
# tensor(-1.6357, grad_fn=<ThAddBackward>)
# tensor(-1.6363, grad_fn=<ThAddBackward>)
# tensor(-1.6370, grad_fn=<ThAddBackward>)
# tensor(-1.6377, grad_fn=<ThAddBackward>)
# tensor(-1.6384, grad_fn=<ThAddBackward>)
# tensor(-1.6392, grad_fn=<ThAddBackward>)
# tensor(-1.6400, grad_fn=<ThAddBackward>)
# tensor(-1.6409, grad_fn=<ThAddBackward>)
# tensor(-1.6419, grad_fn=<ThAddBackward>)
# tensor(-1.6429, grad_fn=<ThAddBackward>)
# tensor(-1.6440, grad_fn=<ThAddBackward>)
# tensor(-1.6451, grad_fn=<ThAddBackward>)
# tensor(-1.6464, grad_fn=<ThAddBackward>)
# tensor(-1.6476, grad_fn=<ThAddBackward>)
# tensor(-1.6490, grad_fn=<ThAddBackward>)
# tensor(-1.6504, grad_fn=<ThAddBackward>)
# tensor(-1.6519, grad_fn=<ThAddBackward>)
# tensor(-1.6534, grad_fn=<ThAddBackward>)
# tensor(-1.6550, grad_fn=<ThAddBackward>)
# tensor(-1.6566, grad_fn=<ThAddBackward>)
# tensor(-1.6581, grad_fn=<ThAddBackward>)
# tensor(-1.6597, grad_fn=<ThAddBackward>)
# tensor(-1.6613, grad_fn=<ThAddBackward>)
# tensor(-1.6628, grad_fn=<ThAddBackward>)
# tensor(-1.6643, grad_fn=<ThAddBackward>)
# tensor(-1.6657, grad_fn=<ThAddBackward>)
# tensor(-1.6671, grad_fn=<ThAddBackward>)
# tensor(-1.6683, grad_fn=<ThAddBackward>)
# tensor(-1.6696, grad_fn=<ThAddBackward>)
# tensor(-1.6707, grad_fn=<ThAddBackward>)
# tensor(-1.6717, grad_fn=<ThAddBackward>)
# tensor(-1.6727, grad_fn=<ThAddBackward>)
# tensor(-1.6736, grad_fn=<ThAddBackward>)
# tensor(-1.6744, grad_fn=<ThAddBackward>)
# tensor(-1.6752, grad_fn=<ThAddBackward>)
# tensor(-1.6759, grad_fn=<ThAddBackward>)
# tensor(-1.6766, grad_fn=<ThAddBackward>)
# tensor(-1.6772, grad_fn=<ThAddBackward>)
# tensor(-1.6778, grad_fn=<ThAddBackward>)
# tensor(-1.6784, grad_fn=<ThAddBackward>)
# tensor(-1.6789, grad_fn=<ThAddBackward>)
# tensor(-1.6794, grad_fn=<ThAddBackward>)
# tensor(-1.6799, grad_fn=<ThAddBackward>)
# tensor(-1.6804, grad_fn=<ThAddBackward>)
# tensor(-1.6808, grad_fn=<ThAddBackward>)
# tensor(-1.6813, grad_fn=<ThAddBackward>)
# tensor(-1.6817, grad_fn=<ThAddBackward>)
# tensor(-1.6821, grad_fn=<ThAddBackward>)
# tensor(-1.6825, grad_fn=<ThAddBackward>)
# tensor(-1.6828, grad_fn=<ThAddBackward>)
# tensor(-1.6832, grad_fn=<ThAddBackward>)
# tensor(-1.6836, grad_fn=<ThAddBackward>)
# tensor(-1.6839, grad_fn=<ThAddBackward>)
# tensor(-1.6843, grad_fn=<ThAddBackward>)
# tensor(-1.6846, grad_fn=<ThAddBackward>)
# tensor(-1.6849, grad_fn=<ThAddBackward>)
# tensor(-1.6852, grad_fn=<ThAddBackward>)
# tensor(-1.6855, grad_fn=<ThAddBackward>)
# tensor(-1.6858, grad_fn=<ThAddBackward>)
# tensor(-1.6861, grad_fn=<ThAddBackward>)
# tensor(-1.6864, grad_fn=<ThAddBackward>)
# tensor(-1.6866, grad_fn=<ThAddBackward>)
# tensor(-1.6869, grad_fn=<ThAddBackward>)
# tensor(-1.6872, grad_fn=<ThAddBackward>)
# tensor(-1.6874, grad_fn=<ThAddBackward>)
# tensor(-1.6877, grad_fn=<ThAddBackward>)
# tensor(-1.6879, grad_fn=<ThAddBackward>)
# tensor(-1.6882, grad_fn=<ThAddBackward>)
# tensor(-1.6884, grad_fn=<ThAddBackward>)
# tensor(-1.6886, grad_fn=<ThAddBackward>)
# tensor(-1.6888, grad_fn=<ThAddBackward>)
# tensor(-1.6891, grad_fn=<ThAddBackward>)
# tensor(-1.6893, grad_fn=<ThAddBackward>)
# tensor(-1.6895, grad_fn=<ThAddBackward>)
# tensor(-1.6897, grad_fn=<ThAddBackward>)
# tensor(-1.6899, grad_fn=<ThAddBackward>)
# tensor(-1.6901, grad_fn=<ThAddBackward>)
# tensor(-1.6903, grad_fn=<ThAddBackward>)
# tensor(-1.6905, grad_fn=<ThAddBackward>)
# tensor(-1.6907, grad_fn=<ThAddBackward>)
# tensor(-1.6909, grad_fn=<ThAddBackward>)
# tensor(-1.6911, grad_fn=<ThAddBackward>)
# tensor(-1.6913, grad_fn=<ThAddBackward>)
# tensor(-1.6915, grad_fn=<ThAddBackward>)
# tensor(-1.6916, grad_fn=<ThAddBackward>)
# tensor(-1.6918, grad_fn=<ThAddBackward>)
# tensor(-1.6920, grad_fn=<ThAddBackward>)
# tensor(-1.6922, grad_fn=<ThAddBackward>)
# tensor(-1.6923, grad_fn=<ThAddBackward>)
# tensor(-1.6925, grad_fn=<ThAddBackward>)
# tensor(-1.6927, grad_fn=<ThAddBackward>)
# tensor(-1.6928, grad_fn=<ThAddBackward>)
# tensor(-1.6930, grad_fn=<ThAddBackward>)
# tensor(-1.6931, grad_fn=<ThAddBackward>)
# tensor(-1.6933, grad_fn=<ThAddBackward>)
# tensor(-1.6934, grad_fn=<ThAddBackward>)
# tensor(-1.6936, grad_fn=<ThAddBackward>)
# tensor(-1.6937, grad_fn=<ThAddBackward>)
# tensor(-1.6939, grad_fn=<ThAddBackward>)
# tensor(-1.6940, grad_fn=<ThAddBackward>)
# tensor(-1.6941, grad_fn=<ThAddBackward>)
# tensor(-1.6943, grad_fn=<ThAddBackward>)
# tensor(-1.6944, grad_fn=<ThAddBackward>)
# tensor(-1.6945, grad_fn=<ThAddBackward>)
# tensor(-1.6947, grad_fn=<ThAddBackward>)
# tensor(-1.6948, grad_fn=<ThAddBackward>)
# tensor(-1.6949, grad_fn=<ThAddBackward>)
# tensor(-1.6951, grad_fn=<ThAddBackward>)
# tensor(-1.6952, grad_fn=<ThAddBackward>)
# tensor(-1.6953, grad_fn=<ThAddBackward>)
# tensor(-1.6954, grad_fn=<ThAddBackward>)
# tensor(-1.6955, grad_fn=<ThAddBackward>)
# tensor(-1.6957, grad_fn=<ThAddBackward>)
# tensor(-1.6958, grad_fn=<ThAddBackward>)
# tensor(-1.6959, grad_fn=<ThAddBackward>)
# tensor(-1.6960, grad_fn=<ThAddBackward>)
# tensor(-1.6961, grad_fn=<ThAddBackward>)
# tensor(-1.6962, grad_fn=<ThAddBackward>)
# tensor(-1.6963, grad_fn=<ThAddBackward>)
# tensor(-1.6965, grad_fn=<ThAddBackward>)
# tensor(-1.6966, grad_fn=<ThAddBackward>)
# tensor(-1.6967, grad_fn=<ThAddBackward>)
# tensor(-1.6968, grad_fn=<ThAddBackward>)
# tensor(-1.6969, grad_fn=<ThAddBackward>)
# tensor(-1.6970, grad_fn=<ThAddBackward>)
# tensor(-1.6971, grad_fn=<ThAddBackward>)
# tensor(-1.6972, grad_fn=<ThAddBackward>)
# tensor(-1.6973, grad_fn=<ThAddBackward>)
# tensor(-1.6974, grad_fn=<ThAddBackward>)
# tensor(-1.6975, grad_fn=<ThAddBackward>)
# tensor(-1.6976, grad_fn=<ThAddBackward>)
# tensor(-1.6977, grad_fn=<ThAddBackward>)
# tensor(-1.6978, grad_fn=<ThAddBackward>)
# tensor(-1.6978, grad_fn=<ThAddBackward>)
# tensor(-1.6979, grad_fn=<ThAddBackward>)
# tensor(-1.6980, grad_fn=<ThAddBackward>)
# tensor(-1.6981, grad_fn=<ThAddBackward>)
# tensor(-1.6982, grad_fn=<ThAddBackward>)
# tensor(-1.6983, grad_fn=<ThAddBackward>)
# tensor(-1.6984, grad_fn=<ThAddBackward>)
# tensor(-1.6985, grad_fn=<ThAddBackward>)
# tensor(-1.6985, grad_fn=<ThAddBackward>)
# tensor(-1.6986, grad_fn=<ThAddBackward>)
# tensor(-1.6987, grad_fn=<ThAddBackward>)
# tensor(-1.6988, grad_fn=<ThAddBackward>)
# tensor(-1.6989, grad_fn=<ThAddBackward>)
# tensor(-1.6990, grad_fn=<ThAddBackward>)
# tensor(-1.6990, grad_fn=<ThAddBackward>)
# tensor(-1.6991, grad_fn=<ThAddBackward>)
# tensor(-1.6992, grad_fn=<ThAddBackward>)
# tensor(-1.6993, grad_fn=<ThAddBackward>)
# tensor(-1.6993, grad_fn=<ThAddBackward>)
# tensor(-1.6994, grad_fn=<ThAddBackward>)
# tensor(-1.6995, grad_fn=<ThAddBackward>)
# tensor(-1.6996, grad_fn=<ThAddBackward>)
# tensor(-1.6996, grad_fn=<ThAddBackward>)
# tensor(-1.6997, grad_fn=<ThAddBackward>)
# tensor(-1.6998, grad_fn=<ThAddBackward>)
# tensor(-1.6999, grad_fn=<ThAddBackward>)
# tensor(-1.6999, grad_fn=<ThAddBackward>)
# tensor(-1.7000, grad_fn=<ThAddBackward>)
# tensor(-1.7001, grad_fn=<ThAddBackward>)
# tensor(-1.7001, grad_fn=<ThAddBackward>)
# tensor(-1.7002, grad_fn=<ThAddBackward>)
# tensor(-1.7003, grad_fn=<ThAddBackward>)
# tensor(-1.7003, grad_fn=<ThAddBackward>)
# tensor(-1.7004, grad_fn=<ThAddBackward>)
# tensor(-1.7005, grad_fn=<ThAddBackward>)
# tensor(-1.7005, grad_fn=<ThAddBackward>)
# tensor(-1.7006, grad_fn=<ThAddBackward>)
# tensor(-1.7007, grad_fn=<ThAddBackward>)
# tensor(-1.7007, grad_fn=<ThAddBackward>)
# tensor(-1.7008, grad_fn=<ThAddBackward>)
# tensor(-1.7009, grad_fn=<ThAddBackward>)
# tensor(-1.7009, grad_fn=<ThAddBackward>)
# tensor(-1.7010, grad_fn=<ThAddBackward>)
# tensor(-1.7010, grad_fn=<ThAddBackward>)
# tensor(-1.7011, grad_fn=<ThAddBackward>)
# tensor(-1.7012, grad_fn=<ThAddBackward>)
# tensor(-1.7012, grad_fn=<ThAddBackward>)
# tensor(-1.7013, grad_fn=<ThAddBackward>)
# tensor(-1.7013, grad_fn=<ThAddBackward>)
# tensor(-1.7014, grad_fn=<ThAddBackward>)
# tensor(-1.7015, grad_fn=<ThAddBackward>)
# tensor(-1.7015, grad_fn=<ThAddBackward>)
# tensor(-1.7016, grad_fn=<ThAddBackward>)
# tensor(-1.7016, grad_fn=<ThAddBackward>)
# tensor(-1.7017, grad_fn=<ThAddBackward>)
# tensor(-1.7017, grad_fn=<ThAddBackward>)
# tensor(-1.7018, grad_fn=<ThAddBackward>)
# tensor(-1.7018, grad_fn=<ThAddBackward>)
# tensor(-1.7019, grad_fn=<ThAddBackward>)
# tensor(-1.7020, grad_fn=<ThAddBackward>)
# tensor(-1.7020, grad_fn=<ThAddBackward>)
# tensor(-1.7021, grad_fn=<ThAddBackward>)
# tensor(-1.7021, grad_fn=<ThAddBackward>)
# tensor(-1.7022, grad_fn=<ThAddBackward>)
# tensor(-1.7022, grad_fn=<ThAddBackward>)
# tensor(-1.7023, grad_fn=<ThAddBackward>)
# tensor(-1.7023, grad_fn=<ThAddBackward>)
# tensor(-1.7024, grad_fn=<ThAddBackward>)
# tensor(-1.7024, grad_fn=<ThAddBackward>)
# tensor(-1.7025, grad_fn=<ThAddBackward>)
# tensor(-1.7025, grad_fn=<ThAddBackward>)
# tensor(-1.7026, grad_fn=<ThAddBackward>)
# tensor(-1.7026, grad_fn=<ThAddBackward>)
# tensor(-1.7027, grad_fn=<ThAddBackward>)
# tensor(-1.7027, grad_fn=<ThAddBackward>)
# tensor(-1.7028, grad_fn=<ThAddBackward>)
# tensor(-1.7028, grad_fn=<ThAddBackward>)
# tensor(-1.7028, grad_fn=<ThAddBackward>)
# tensor(-1.7029, grad_fn=<ThAddBackward>)
# tensor(-1.7029, grad_fn=<ThAddBackward>)
# tensor(-1.7030, grad_fn=<ThAddBackward>)
# tensor(-1.7030, grad_fn=<ThAddBackward>)
# tensor(-1.7031, grad_fn=<ThAddBackward>)
# tensor(-1.7031, grad_fn=<ThAddBackward>)
# tensor(-1.7032, grad_fn=<ThAddBackward>)
# tensor(-1.7032, grad_fn=<ThAddBackward>)
# tensor(-1.7033, grad_fn=<ThAddBackward>)
# tensor(-1.7033, grad_fn=<ThAddBackward>)
# tensor(-1.7033, grad_fn=<ThAddBackward>)
# tensor(-1.7034, grad_fn=<ThAddBackward>)
# tensor(-1.7034, grad_fn=<ThAddBackward>)
# tensor(-1.7035, grad_fn=<ThAddBackward>)
# tensor(-1.7035, grad_fn=<ThAddBackward>)
# tensor(-1.7036, grad_fn=<ThAddBackward>)
# tensor(-1.7036, grad_fn=<ThAddBackward>)
# tensor(-1.7036, grad_fn=<ThAddBackward>)
# tensor(-1.7037, grad_fn=<ThAddBackward>)
# tensor(-1.7037, grad_fn=<ThAddBackward>)
# tensor(-1.7038, grad_fn=<ThAddBackward>)
# tensor(-1.7038, grad_fn=<ThAddBackward>)
# tensor(-1.7038, grad_fn=<ThAddBackward>)
# tensor(-1.7039, grad_fn=<ThAddBackward>)
# tensor(-1.7039, grad_fn=<ThAddBackward>)
# tensor(-1.7040, grad_fn=<ThAddBackward>)
# tensor(-1.7040, grad_fn=<ThAddBackward>)
# tensor(-1.7040, grad_fn=<ThAddBackward>)
# tensor(-1.7041, grad_fn=<ThAddBackward>)
# tensor(-1.7041, grad_fn=<ThAddBackward>)
# tensor(-1.7041, grad_fn=<ThAddBackward>)
# tensor(-1.7042, grad_fn=<ThAddBackward>)
# tensor(-1.7042, grad_fn=<ThAddBackward>)
# tensor(-1.7043, grad_fn=<ThAddBackward>)
# tensor(-1.7043, grad_fn=<ThAddBackward>)
# tensor(-1.7043, grad_fn=<ThAddBackward>)
# tensor(-1.7044, grad_fn=<ThAddBackward>)
# tensor(-1.7044, grad_fn=<ThAddBackward>)
# tensor(-1.7044, grad_fn=<ThAddBackward>)
# tensor(-1.7045, grad_fn=<ThAddBackward>)
# tensor(-1.7045, grad_fn=<ThAddBackward>)
# tensor(-1.7046, grad_fn=<ThAddBackward>)
# tensor(-1.7046, grad_fn=<ThAddBackward>)
# tensor(-1.7046, grad_fn=<ThAddBackward>)
# tensor(-1.7047, grad_fn=<ThAddBackward>)
# tensor(-1.7047, grad_fn=<ThAddBackward>)
# tensor(-1.7047, grad_fn=<ThAddBackward>)
# tensor(-1.7048, grad_fn=<ThAddBackward>)
# tensor(-1.7048, grad_fn=<ThAddBackward>)
# tensor(-1.7048, grad_fn=<ThAddBackward>)
# tensor(-1.7049, grad_fn=<ThAddBackward>)
# tensor(-1.7049, grad_fn=<ThAddBackward>)
# tensor(-1.7049, grad_fn=<ThAddBackward>)
# tensor(-1.7050, grad_fn=<ThAddBackward>)
# tensor(-1.7050, grad_fn=<ThAddBackward>)
# tensor(-1.7050, grad_fn=<ThAddBackward>)
# tensor(-1.7051, grad_fn=<ThAddBackward>)
# tensor(-1.7051, grad_fn=<ThAddBackward>)
# tensor(-1.7051, grad_fn=<ThAddBackward>)
# tensor(-1.7052, grad_fn=<ThAddBackward>)
# tensor(-1.7052, grad_fn=<ThAddBackward>)
# tensor(-1.7052, grad_fn=<ThAddBackward>)
# tensor(-1.7053, grad_fn=<ThAddBackward>)
# tensor(-1.7053, grad_fn=<ThAddBackward>)
# tensor(-1.7053, grad_fn=<ThAddBackward>)
# tensor(-1.7054, grad_fn=<ThAddBackward>)
# tensor(-1.7054, grad_fn=<ThAddBackward>)
# tensor(-1.7054, grad_fn=<ThAddBackward>)
# tensor(-1.7054, grad_fn=<ThAddBackward>)
# tensor(-1.7055, grad_fn=<ThAddBackward>)
# tensor(-1.7055, grad_fn=<ThAddBackward>)
# tensor(-1.7055, grad_fn=<ThAddBackward>)
# tensor(-1.7056, grad_fn=<ThAddBackward>)

# %%
task2_loss
# Out:
# tensor(-0.1259, grad_fn=<NllLossBackward>)

# %%
torch.stack([torch.tensor([[1,2,3,4]]), torch.tensor([[4,3,2,1]])])

# %%
print(type([torch.tensor([[1,2,3,4]]), torch.tensor([[4,3,2,1]])]))

# %%
type(torch.tensor([[1,2,3,4]]))

# %%
model.lin_task2.weight.shape
# Out:
# torch.Size([8, 30])

# %%
model.lin_task2.bias
# Out:
# Parameter containing:
# tensor([ 0.0158,  0.1807,  0.0529, -0.1628, -0.1240,  0.0059, -0.1141,  0.1313],
#        requires_grad=True)

# %%
class Model1b(nn.Module):
    def __init__(self, input_dim, pointer_dim):
        super(Model1b, self).__init__()
        self.input_dim = input_dim
        self.pointer_dim = pointer_dim
        
        self.lin_pointer = nn.Linear(input_dim, pointer_dim)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        pointer_outputs = []
        
        for x_t in x.reshape(len(x), 1, self.input_dim):
#             h_t, c_t = self.lstm(x_t, (h_t, c_t))
            pointer_outputs.append(self.softmax(self.lin_pointer(x_t)))
        
        return torch.stack(pointer_outputs).reshape(len(x), self.pointer_dim)

# %%
model = Model1b(7, 7)
model.double()

optimizer = optim.Adam(model.parameters())
inputs, pointer_outputs, task1_outputs, task2_outputs = training_sequence_1([2,4,6,0,5,3,1])
X = vectorize_2d(inputs, 7)
Y1 = vectorize_2d(pointer_outputs, 7)


def closure():
    optimizer.zero_grad()
    pred1 = model(X)
    pointer_loss = nn.functional.nll_loss(pred1, pointer_outputs)
    loss = pointer_loss
#     pointer_loss.backward(retain_graph=True)
#     task1_loss.backward(retain_graph=True)
#     task2_loss.backward(retain_graph=True)
    
    loss.backward()
    return loss #pointer_loss, task1_loss, task2_loss

# %%
for i in range(10000):
    loss = optimizer.step(closure)
    print(loss)
# Out:
# tensor(-0.1501, grad_fn=<NllLossBackward>)
# tensor(-0.1504, grad_fn=<NllLossBackward>)
# tensor(-0.1506, grad_fn=<NllLossBackward>)
# tensor(-0.1508, grad_fn=<NllLossBackward>)
# tensor(-0.1511, grad_fn=<NllLossBackward>)
# tensor(-0.1513, grad_fn=<NllLossBackward>)
# tensor(-0.1516, grad_fn=<NllLossBackward>)
# tensor(-0.1518, grad_fn=<NllLossBackward>)
# tensor(-0.1520, grad_fn=<NllLossBackward>)
# tensor(-0.1523, grad_fn=<NllLossBackward>)
# tensor(-0.1525, grad_fn=<NllLossBackward>)
# tensor(-0.1527, grad_fn=<NllLossBackward>)
# tensor(-0.1530, grad_fn=<NllLossBackward>)
# tensor(-0.1532, grad_fn=<NllLossBackward>)
# tensor(-0.1535, grad_fn=<NllLossBackward>)
# tensor(-0.1537, grad_fn=<NllLossBackward>)
# tensor(-0.1539, grad_fn=<NllLossBackward>)
# tensor(-0.1542, grad_fn=<NllLossBackward>)
# tensor(-0.1544, grad_fn=<NllLossBackward>)
# tensor(-0.1547, grad_fn=<NllLossBackward>)
# tensor(-0.1549, grad_fn=<NllLossBackward>)
# tensor(-0.1551, grad_fn=<NllLossBackward>)
# tensor(-0.1554, grad_fn=<NllLossBackward>)
# tensor(-0.1556, grad_fn=<NllLossBackward>)
# tensor(-0.1559, grad_fn=<NllLossBackward>)
# tensor(-0.1561, grad_fn=<NllLossBackward>)
# tensor(-0.1564, grad_fn=<NllLossBackward>)
# tensor(-0.1566, grad_fn=<NllLossBackward>)
# tensor(-0.1569, grad_fn=<NllLossBackward>)
# tensor(-0.1571, grad_fn=<NllLossBackward>)
# tensor(-0.1573, grad_fn=<NllLossBackward>)
# tensor(-0.1576, grad_fn=<NllLossBackward>)
# tensor(-0.1578, grad_fn=<NllLossBackward>)
# tensor(-0.1581, grad_fn=<NllLossBackward>)
# tensor(-0.1583, grad_fn=<NllLossBackward>)
# tensor(-0.1586, grad_fn=<NllLossBackward>)
# tensor(-0.1588, grad_fn=<NllLossBackward>)
# tensor(-0.1591, grad_fn=<NllLossBackward>)
# tensor(-0.1593, grad_fn=<NllLossBackward>)
# tensor(-0.1596, grad_fn=<NllLossBackward>)
# tensor(-0.1598, grad_fn=<NllLossBackward>)
# tensor(-0.1601, grad_fn=<NllLossBackward>)
# tensor(-0.1603, grad_fn=<NllLossBackward>)
# tensor(-0.1606, grad_fn=<NllLossBackward>)
# tensor(-0.1608, grad_fn=<NllLossBackward>)
# tensor(-0.1611, grad_fn=<NllLossBackward>)
# tensor(-0.1613, grad_fn=<NllLossBackward>)
# tensor(-0.1616, grad_fn=<NllLossBackward>)
# tensor(-0.1618, grad_fn=<NllLossBackward>)
# tensor(-0.1621, grad_fn=<NllLossBackward>)
# tensor(-0.1623, grad_fn=<NllLossBackward>)
# tensor(-0.1626, grad_fn=<NllLossBackward>)
# tensor(-0.1628, grad_fn=<NllLossBackward>)
# tensor(-0.1631, grad_fn=<NllLossBackward>)
# tensor(-0.1633, grad_fn=<NllLossBackward>)
# tensor(-0.1636, grad_fn=<NllLossBackward>)
# tensor(-0.1638, grad_fn=<NllLossBackward>)
# tensor(-0.1641, grad_fn=<NllLossBackward>)
# tensor(-0.1644, grad_fn=<NllLossBackward>)
# tensor(-0.1646, grad_fn=<NllLossBackward>)
# tensor(-0.1649, grad_fn=<NllLossBackward>)
# tensor(-0.1651, grad_fn=<NllLossBackward>)
# tensor(-0.1654, grad_fn=<NllLossBackward>)
# tensor(-0.1656, grad_fn=<NllLossBackward>)
# tensor(-0.1659, grad_fn=<NllLossBackward>)
# tensor(-0.1662, grad_fn=<NllLossBackward>)
# tensor(-0.1664, grad_fn=<NllLossBackward>)
# tensor(-0.1667, grad_fn=<NllLossBackward>)
# tensor(-0.1669, grad_fn=<NllLossBackward>)
# tensor(-0.1672, grad_fn=<NllLossBackward>)
# tensor(-0.1675, grad_fn=<NllLossBackward>)
# tensor(-0.1677, grad_fn=<NllLossBackward>)
# tensor(-0.1680, grad_fn=<NllLossBackward>)
# tensor(-0.1682, grad_fn=<NllLossBackward>)
# tensor(-0.1685, grad_fn=<NllLossBackward>)
# tensor(-0.1688, grad_fn=<NllLossBackward>)
# tensor(-0.1690, grad_fn=<NllLossBackward>)
# tensor(-0.1693, grad_fn=<NllLossBackward>)
# tensor(-0.1696, grad_fn=<NllLossBackward>)
# tensor(-0.1698, grad_fn=<NllLossBackward>)
# tensor(-0.1701, grad_fn=<NllLossBackward>)
# tensor(-0.1703, grad_fn=<NllLossBackward>)
# tensor(-0.1706, grad_fn=<NllLossBackward>)
# tensor(-0.1709, grad_fn=<NllLossBackward>)
# tensor(-0.1711, grad_fn=<NllLossBackward>)
# tensor(-0.1714, grad_fn=<NllLossBackward>)
# tensor(-0.1717, grad_fn=<NllLossBackward>)
# tensor(-0.1719, grad_fn=<NllLossBackward>)
# tensor(-0.1722, grad_fn=<NllLossBackward>)
# tensor(-0.1725, grad_fn=<NllLossBackward>)
# tensor(-0.1727, grad_fn=<NllLossBackward>)
# tensor(-0.1730, grad_fn=<NllLossBackward>)
# tensor(-0.1733, grad_fn=<NllLossBackward>)
# tensor(-0.1735, grad_fn=<NllLossBackward>)
# tensor(-0.1738, grad_fn=<NllLossBackward>)
# tensor(-0.1741, grad_fn=<NllLossBackward>)
# tensor(-0.1744, grad_fn=<NllLossBackward>)
# tensor(-0.1746, grad_fn=<NllLossBackward>)
# tensor(-0.1749, grad_fn=<NllLossBackward>)
# tensor(-0.1752, grad_fn=<NllLossBackward>)
# tensor(-0.1754, grad_fn=<NllLossBackward>)
# tensor(-0.1757, grad_fn=<NllLossBackward>)
# tensor(-0.1760, grad_fn=<NllLossBackward>)
# tensor(-0.1763, grad_fn=<NllLossBackward>)
# tensor(-0.1765, grad_fn=<NllLossBackward>)
# tensor(-0.1768, grad_fn=<NllLossBackward>)
# tensor(-0.1771, grad_fn=<NllLossBackward>)
# tensor(-0.1774, grad_fn=<NllLossBackward>)
# tensor(-0.1776, grad_fn=<NllLossBackward>)
# tensor(-0.1779, grad_fn=<NllLossBackward>)
# tensor(-0.1782, grad_fn=<NllLossBackward>)
# tensor(-0.1785, grad_fn=<NllLossBackward>)
# tensor(-0.1787, grad_fn=<NllLossBackward>)
# tensor(-0.1790, grad_fn=<NllLossBackward>)
# tensor(-0.1793, grad_fn=<NllLossBackward>)
# tensor(-0.1796, grad_fn=<NllLossBackward>)
# tensor(-0.1798, grad_fn=<NllLossBackward>)
# tensor(-0.1801, grad_fn=<NllLossBackward>)
# tensor(-0.1804, grad_fn=<NllLossBackward>)
# tensor(-0.1807, grad_fn=<NllLossBackward>)
# tensor(-0.1810, grad_fn=<NllLossBackward>)
# tensor(-0.1812, grad_fn=<NllLossBackward>)
# tensor(-0.1815, grad_fn=<NllLossBackward>)
# tensor(-0.1818, grad_fn=<NllLossBackward>)
# tensor(-0.1821, grad_fn=<NllLossBackward>)
# tensor(-0.1824, grad_fn=<NllLossBackward>)
# tensor(-0.1826, grad_fn=<NllLossBackward>)
# tensor(-0.1829, grad_fn=<NllLossBackward>)
# tensor(-0.1832, grad_fn=<NllLossBackward>)
# tensor(-0.1835, grad_fn=<NllLossBackward>)
# tensor(-0.1838, grad_fn=<NllLossBackward>)
# tensor(-0.1841, grad_fn=<NllLossBackward>)
# tensor(-0.1843, grad_fn=<NllLossBackward>)
# tensor(-0.1846, grad_fn=<NllLossBackward>)
# tensor(-0.1849, grad_fn=<NllLossBackward>)
# tensor(-0.1852, grad_fn=<NllLossBackward>)
# tensor(-0.1855, grad_fn=<NllLossBackward>)
# tensor(-0.1858, grad_fn=<NllLossBackward>)
# tensor(-0.1861, grad_fn=<NllLossBackward>)
# tensor(-0.1864, grad_fn=<NllLossBackward>)
# tensor(-0.1866, grad_fn=<NllLossBackward>)
# tensor(-0.1869, grad_fn=<NllLossBackward>)
# tensor(-0.1872, grad_fn=<NllLossBackward>)
# tensor(-0.1875, grad_fn=<NllLossBackward>)
# tensor(-0.1878, grad_fn=<NllLossBackward>)
# tensor(-0.1881, grad_fn=<NllLossBackward>)
# tensor(-0.1884, grad_fn=<NllLossBackward>)
# tensor(-0.1887, grad_fn=<NllLossBackward>)
# tensor(-0.1890, grad_fn=<NllLossBackward>)
# tensor(-0.1892, grad_fn=<NllLossBackward>)
# tensor(-0.1895, grad_fn=<NllLossBackward>)
# tensor(-0.1898, grad_fn=<NllLossBackward>)
# tensor(-0.1901, grad_fn=<NllLossBackward>)
# tensor(-0.1904, grad_fn=<NllLossBackward>)
# tensor(-0.1907, grad_fn=<NllLossBackward>)
# tensor(-0.1910, grad_fn=<NllLossBackward>)
# tensor(-0.1913, grad_fn=<NllLossBackward>)
# tensor(-0.1916, grad_fn=<NllLossBackward>)
# tensor(-0.1919, grad_fn=<NllLossBackward>)
# tensor(-0.1922, grad_fn=<NllLossBackward>)
# tensor(-0.1925, grad_fn=<NllLossBackward>)
# tensor(-0.1928, grad_fn=<NllLossBackward>)
# tensor(-0.1931, grad_fn=<NllLossBackward>)
# tensor(-0.1934, grad_fn=<NllLossBackward>)
# tensor(-0.1937, grad_fn=<NllLossBackward>)
# tensor(-0.1940, grad_fn=<NllLossBackward>)
# tensor(-0.1943, grad_fn=<NllLossBackward>)
# tensor(-0.1946, grad_fn=<NllLossBackward>)
# tensor(-0.1949, grad_fn=<NllLossBackward>)
# tensor(-0.1952, grad_fn=<NllLossBackward>)
# tensor(-0.1955, grad_fn=<NllLossBackward>)
# tensor(-0.1958, grad_fn=<NllLossBackward>)
# tensor(-0.1961, grad_fn=<NllLossBackward>)
# tensor(-0.1964, grad_fn=<NllLossBackward>)
# tensor(-0.1967, grad_fn=<NllLossBackward>)
# tensor(-0.1970, grad_fn=<NllLossBackward>)
# tensor(-0.1973, grad_fn=<NllLossBackward>)
# tensor(-0.1976, grad_fn=<NllLossBackward>)
# tensor(-0.1979, grad_fn=<NllLossBackward>)
# tensor(-0.1982, grad_fn=<NllLossBackward>)
# tensor(-0.1985, grad_fn=<NllLossBackward>)
# tensor(-0.1988, grad_fn=<NllLossBackward>)
# tensor(-0.1991, grad_fn=<NllLossBackward>)
# tensor(-0.1994, grad_fn=<NllLossBackward>)
# tensor(-0.1997, grad_fn=<NllLossBackward>)
# tensor(-0.2000, grad_fn=<NllLossBackward>)
# tensor(-0.2003, grad_fn=<NllLossBackward>)
# tensor(-0.2006, grad_fn=<NllLossBackward>)
# tensor(-0.2009, grad_fn=<NllLossBackward>)
# tensor(-0.2012, grad_fn=<NllLossBackward>)
# tensor(-0.2015, grad_fn=<NllLossBackward>)
# tensor(-0.2018, grad_fn=<NllLossBackward>)
# tensor(-0.2022, grad_fn=<NllLossBackward>)
# tensor(-0.2025, grad_fn=<NllLossBackward>)
# tensor(-0.2028, grad_fn=<NllLossBackward>)
# tensor(-0.2031, grad_fn=<NllLossBackward>)
# tensor(-0.2034, grad_fn=<NllLossBackward>)
# tensor(-0.2037, grad_fn=<NllLossBackward>)
# tensor(-0.2040, grad_fn=<NllLossBackward>)
# tensor(-0.2043, grad_fn=<NllLossBackward>)
# tensor(-0.2046, grad_fn=<NllLossBackward>)
# tensor(-0.2050, grad_fn=<NllLossBackward>)
# tensor(-0.2053, grad_fn=<NllLossBackward>)
# tensor(-0.2056, grad_fn=<NllLossBackward>)
# tensor(-0.2059, grad_fn=<NllLossBackward>)
# tensor(-0.2062, grad_fn=<NllLossBackward>)
# tensor(-0.2065, grad_fn=<NllLossBackward>)
# tensor(-0.2068, grad_fn=<NllLossBackward>)
# tensor(-0.2072, grad_fn=<NllLossBackward>)
# tensor(-0.2075, grad_fn=<NllLossBackward>)
# tensor(-0.2078, grad_fn=<NllLossBackward>)
# tensor(-0.2081, grad_fn=<NllLossBackward>)
# tensor(-0.2084, grad_fn=<NllLossBackward>)
# tensor(-0.2087, grad_fn=<NllLossBackward>)
# tensor(-0.2091, grad_fn=<NllLossBackward>)
# tensor(-0.2094, grad_fn=<NllLossBackward>)
# tensor(-0.2097, grad_fn=<NllLossBackward>)
# tensor(-0.2100, grad_fn=<NllLossBackward>)
# tensor(-0.2103, grad_fn=<NllLossBackward>)
# tensor(-0.2106, grad_fn=<NllLossBackward>)
# tensor(-0.2110, grad_fn=<NllLossBackward>)
# tensor(-0.2113, grad_fn=<NllLossBackward>)
# tensor(-0.2116, grad_fn=<NllLossBackward>)
# tensor(-0.2119, grad_fn=<NllLossBackward>)
# tensor(-0.2123, grad_fn=<NllLossBackward>)
# tensor(-0.2126, grad_fn=<NllLossBackward>)
# tensor(-0.2129, grad_fn=<NllLossBackward>)
# tensor(-0.2132, grad_fn=<NllLossBackward>)
# tensor(-0.2135, grad_fn=<NllLossBackward>)
# tensor(-0.2139, grad_fn=<NllLossBackward>)
# tensor(-0.2142, grad_fn=<NllLossBackward>)
# tensor(-0.2145, grad_fn=<NllLossBackward>)
# tensor(-0.2148, grad_fn=<NllLossBackward>)
# tensor(-0.2152, grad_fn=<NllLossBackward>)
# tensor(-0.2155, grad_fn=<NllLossBackward>)
# tensor(-0.2158, grad_fn=<NllLossBackward>)
# tensor(-0.2162, grad_fn=<NllLossBackward>)
# tensor(-0.2165, grad_fn=<NllLossBackward>)
# tensor(-0.2168, grad_fn=<NllLossBackward>)
# tensor(-0.2171, grad_fn=<NllLossBackward>)
# tensor(-0.2175, grad_fn=<NllLossBackward>)
# tensor(-0.2178, grad_fn=<NllLossBackward>)
# tensor(-0.2181, grad_fn=<NllLossBackward>)
# tensor(-0.2185, grad_fn=<NllLossBackward>)
# tensor(-0.2188, grad_fn=<NllLossBackward>)
# tensor(-0.2191, grad_fn=<NllLossBackward>)
# tensor(-0.2194, grad_fn=<NllLossBackward>)
# tensor(-0.2198, grad_fn=<NllLossBackward>)
# tensor(-0.2201, grad_fn=<NllLossBackward>)
# tensor(-0.2204, grad_fn=<NllLossBackward>)
# tensor(-0.2208, grad_fn=<NllLossBackward>)
# tensor(-0.2211, grad_fn=<NllLossBackward>)
# tensor(-0.2214, grad_fn=<NllLossBackward>)
# tensor(-0.2218, grad_fn=<NllLossBackward>)
# tensor(-0.2221, grad_fn=<NllLossBackward>)
# tensor(-0.2224, grad_fn=<NllLossBackward>)
# tensor(-0.2228, grad_fn=<NllLossBackward>)
# tensor(-0.2231, grad_fn=<NllLossBackward>)
# tensor(-0.2235, grad_fn=<NllLossBackward>)
# tensor(-0.2238, grad_fn=<NllLossBackward>)
# tensor(-0.2241, grad_fn=<NllLossBackward>)
# tensor(-0.2245, grad_fn=<NllLossBackward>)
# tensor(-0.2248, grad_fn=<NllLossBackward>)
# tensor(-0.2251, grad_fn=<NllLossBackward>)
# tensor(-0.2255, grad_fn=<NllLossBackward>)
# tensor(-0.2258, grad_fn=<NllLossBackward>)
# tensor(-0.2262, grad_fn=<NllLossBackward>)
# tensor(-0.2265, grad_fn=<NllLossBackward>)
# tensor(-0.2268, grad_fn=<NllLossBackward>)
# tensor(-0.2272, grad_fn=<NllLossBackward>)
# tensor(-0.2275, grad_fn=<NllLossBackward>)
# tensor(-0.2279, grad_fn=<NllLossBackward>)
# tensor(-0.2282, grad_fn=<NllLossBackward>)
# tensor(-0.2285, grad_fn=<NllLossBackward>)
# tensor(-0.2289, grad_fn=<NllLossBackward>)
# tensor(-0.2292, grad_fn=<NllLossBackward>)
# tensor(-0.2296, grad_fn=<NllLossBackward>)
# tensor(-0.2299, grad_fn=<NllLossBackward>)
# tensor(-0.2303, grad_fn=<NllLossBackward>)
# tensor(-0.2306, grad_fn=<NllLossBackward>)
# tensor(-0.2309, grad_fn=<NllLossBackward>)
# tensor(-0.2313, grad_fn=<NllLossBackward>)
# tensor(-0.2316, grad_fn=<NllLossBackward>)
# tensor(-0.2320, grad_fn=<NllLossBackward>)
# tensor(-0.2323, grad_fn=<NllLossBackward>)
# tensor(-0.2327, grad_fn=<NllLossBackward>)
# tensor(-0.2330, grad_fn=<NllLossBackward>)
# tensor(-0.2334, grad_fn=<NllLossBackward>)
# tensor(-0.2337, grad_fn=<NllLossBackward>)
# tensor(-0.2341, grad_fn=<NllLossBackward>)
# tensor(-0.2344, grad_fn=<NllLossBackward>)
# tensor(-0.2348, grad_fn=<NllLossBackward>)
# tensor(-0.2351, grad_fn=<NllLossBackward>)
# tensor(-0.2355, grad_fn=<NllLossBackward>)
# tensor(-0.2358, grad_fn=<NllLossBackward>)
# tensor(-0.2362, grad_fn=<NllLossBackward>)
# tensor(-0.2365, grad_fn=<NllLossBackward>)
# tensor(-0.2369, grad_fn=<NllLossBackward>)
# tensor(-0.2372, grad_fn=<NllLossBackward>)
# tensor(-0.2376, grad_fn=<NllLossBackward>)
# tensor(-0.2379, grad_fn=<NllLossBackward>)
# tensor(-0.2383, grad_fn=<NllLossBackward>)
# tensor(-0.2386, grad_fn=<NllLossBackward>)
# tensor(-0.2390, grad_fn=<NllLossBackward>)
# tensor(-0.2393, grad_fn=<NllLossBackward>)
# tensor(-0.2397, grad_fn=<NllLossBackward>)
# tensor(-0.2400, grad_fn=<NllLossBackward>)
# tensor(-0.2404, grad_fn=<NllLossBackward>)
# tensor(-0.2407, grad_fn=<NllLossBackward>)
# tensor(-0.2411, grad_fn=<NllLossBackward>)
# tensor(-0.2414, grad_fn=<NllLossBackward>)
# tensor(-0.2418, grad_fn=<NllLossBackward>)
# tensor(-0.2422, grad_fn=<NllLossBackward>)
# tensor(-0.2425, grad_fn=<NllLossBackward>)
# tensor(-0.2429, grad_fn=<NllLossBackward>)
# tensor(-0.2432, grad_fn=<NllLossBackward>)
# tensor(-0.2436, grad_fn=<NllLossBackward>)
# tensor(-0.2439, grad_fn=<NllLossBackward>)
# tensor(-0.2443, grad_fn=<NllLossBackward>)
# tensor(-0.2447, grad_fn=<NllLossBackward>)
# tensor(-0.2450, grad_fn=<NllLossBackward>)
# tensor(-0.2454, grad_fn=<NllLossBackward>)
# tensor(-0.2457, grad_fn=<NllLossBackward>)
# tensor(-0.2461, grad_fn=<NllLossBackward>)
# tensor(-0.2465, grad_fn=<NllLossBackward>)
# tensor(-0.2468, grad_fn=<NllLossBackward>)
# tensor(-0.2472, grad_fn=<NllLossBackward>)
# tensor(-0.2475, grad_fn=<NllLossBackward>)
# tensor(-0.2479, grad_fn=<NllLossBackward>)
# tensor(-0.2483, grad_fn=<NllLossBackward>)
# tensor(-0.2486, grad_fn=<NllLossBackward>)
# tensor(-0.2490, grad_fn=<NllLossBackward>)
# tensor(-0.2493, grad_fn=<NllLossBackward>)
# tensor(-0.2497, grad_fn=<NllLossBackward>)
# tensor(-0.2501, grad_fn=<NllLossBackward>)
# tensor(-0.2504, grad_fn=<NllLossBackward>)
# tensor(-0.2508, grad_fn=<NllLossBackward>)
# tensor(-0.2511, grad_fn=<NllLossBackward>)
# tensor(-0.2515, grad_fn=<NllLossBackward>)
# tensor(-0.2519, grad_fn=<NllLossBackward>)
# tensor(-0.2522, grad_fn=<NllLossBackward>)
# tensor(-0.2526, grad_fn=<NllLossBackward>)
# tensor(-0.2530, grad_fn=<NllLossBackward>)
# tensor(-0.2533, grad_fn=<NllLossBackward>)
# tensor(-0.2537, grad_fn=<NllLossBackward>)
# tensor(-0.2541, grad_fn=<NllLossBackward>)
# tensor(-0.2544, grad_fn=<NllLossBackward>)
# tensor(-0.2548, grad_fn=<NllLossBackward>)
# tensor(-0.2552, grad_fn=<NllLossBackward>)
# tensor(-0.2555, grad_fn=<NllLossBackward>)
# tensor(-0.2559, grad_fn=<NllLossBackward>)
# tensor(-0.2563, grad_fn=<NllLossBackward>)
# tensor(-0.2566, grad_fn=<NllLossBackward>)
# tensor(-0.2570, grad_fn=<NllLossBackward>)
# tensor(-0.2574, grad_fn=<NllLossBackward>)
# tensor(-0.2577, grad_fn=<NllLossBackward>)
# tensor(-0.2581, grad_fn=<NllLossBackward>)
# tensor(-0.2585, grad_fn=<NllLossBackward>)
# tensor(-0.2588, grad_fn=<NllLossBackward>)
# tensor(-0.2592, grad_fn=<NllLossBackward>)
# tensor(-0.2596, grad_fn=<NllLossBackward>)
# tensor(-0.2599, grad_fn=<NllLossBackward>)
# tensor(-0.2603, grad_fn=<NllLossBackward>)
# tensor(-0.2607, grad_fn=<NllLossBackward>)
# tensor(-0.2610, grad_fn=<NllLossBackward>)
# tensor(-0.2614, grad_fn=<NllLossBackward>)
# tensor(-0.2618, grad_fn=<NllLossBackward>)
# tensor(-0.2621, grad_fn=<NllLossBackward>)
# tensor(-0.2625, grad_fn=<NllLossBackward>)
# tensor(-0.2629, grad_fn=<NllLossBackward>)
# tensor(-0.2632, grad_fn=<NllLossBackward>)
# tensor(-0.2636, grad_fn=<NllLossBackward>)
# tensor(-0.2640, grad_fn=<NllLossBackward>)
# tensor(-0.2644, grad_fn=<NllLossBackward>)
# tensor(-0.2647, grad_fn=<NllLossBackward>)
# tensor(-0.2651, grad_fn=<NllLossBackward>)
# tensor(-0.2655, grad_fn=<NllLossBackward>)
# tensor(-0.2658, grad_fn=<NllLossBackward>)
# tensor(-0.2662, grad_fn=<NllLossBackward>)
# tensor(-0.2666, grad_fn=<NllLossBackward>)
# tensor(-0.2670, grad_fn=<NllLossBackward>)
# tensor(-0.2673, grad_fn=<NllLossBackward>)
# tensor(-0.2677, grad_fn=<NllLossBackward>)
# tensor(-0.2681, grad_fn=<NllLossBackward>)
# tensor(-0.2684, grad_fn=<NllLossBackward>)
# tensor(-0.2688, grad_fn=<NllLossBackward>)
# tensor(-0.2692, grad_fn=<NllLossBackward>)
# tensor(-0.2696, grad_fn=<NllLossBackward>)
# tensor(-0.2699, grad_fn=<NllLossBackward>)
# tensor(-0.2703, grad_fn=<NllLossBackward>)
# tensor(-0.2707, grad_fn=<NllLossBackward>)
# tensor(-0.2711, grad_fn=<NllLossBackward>)
# tensor(-0.2714, grad_fn=<NllLossBackward>)
# tensor(-0.2718, grad_fn=<NllLossBackward>)
# tensor(-0.2722, grad_fn=<NllLossBackward>)
# tensor(-0.2725, grad_fn=<NllLossBackward>)
# tensor(-0.2729, grad_fn=<NllLossBackward>)
# tensor(-0.2733, grad_fn=<NllLossBackward>)
# tensor(-0.2737, grad_fn=<NllLossBackward>)
# tensor(-0.2740, grad_fn=<NllLossBackward>)
# tensor(-0.2744, grad_fn=<NllLossBackward>)
# tensor(-0.2748, grad_fn=<NllLossBackward>)
# tensor(-0.2752, grad_fn=<NllLossBackward>)
# tensor(-0.2755, grad_fn=<NllLossBackward>)
# tensor(-0.2759, grad_fn=<NllLossBackward>)
# tensor(-0.2763, grad_fn=<NllLossBackward>)
# tensor(-0.2767, grad_fn=<NllLossBackward>)
# tensor(-0.2770, grad_fn=<NllLossBackward>)
# tensor(-0.2774, grad_fn=<NllLossBackward>)
# tensor(-0.2778, grad_fn=<NllLossBackward>)
# tensor(-0.2782, grad_fn=<NllLossBackward>)
# tensor(-0.2785, grad_fn=<NllLossBackward>)
# tensor(-0.2789, grad_fn=<NllLossBackward>)
# tensor(-0.2793, grad_fn=<NllLossBackward>)
# tensor(-0.2797, grad_fn=<NllLossBackward>)
# tensor(-0.2800, grad_fn=<NllLossBackward>)
# tensor(-0.2804, grad_fn=<NllLossBackward>)
# tensor(-0.2808, grad_fn=<NllLossBackward>)
# tensor(-0.2812, grad_fn=<NllLossBackward>)
# tensor(-0.2816, grad_fn=<NllLossBackward>)
# tensor(-0.2819, grad_fn=<NllLossBackward>)
# tensor(-0.2823, grad_fn=<NllLossBackward>)
# tensor(-0.2827, grad_fn=<NllLossBackward>)
# tensor(-0.2831, grad_fn=<NllLossBackward>)
# tensor(-0.2834, grad_fn=<NllLossBackward>)
# tensor(-0.2838, grad_fn=<NllLossBackward>)
# tensor(-0.2842, grad_fn=<NllLossBackward>)
# tensor(-0.2846, grad_fn=<NllLossBackward>)
# tensor(-0.2849, grad_fn=<NllLossBackward>)
# tensor(-0.2853, grad_fn=<NllLossBackward>)
# tensor(-0.2857, grad_fn=<NllLossBackward>)
# tensor(-0.2861, grad_fn=<NllLossBackward>)
# tensor(-0.2864, grad_fn=<NllLossBackward>)
# tensor(-0.2868, grad_fn=<NllLossBackward>)
# tensor(-0.2872, grad_fn=<NllLossBackward>)
# tensor(-0.2876, grad_fn=<NllLossBackward>)
# tensor(-0.2880, grad_fn=<NllLossBackward>)
# tensor(-0.2883, grad_fn=<NllLossBackward>)
# tensor(-0.2887, grad_fn=<NllLossBackward>)
# tensor(-0.2891, grad_fn=<NllLossBackward>)
# tensor(-0.2895, grad_fn=<NllLossBackward>)
# tensor(-0.2898, grad_fn=<NllLossBackward>)
# tensor(-0.2902, grad_fn=<NllLossBackward>)
# tensor(-0.2906, grad_fn=<NllLossBackward>)
# tensor(-0.2910, grad_fn=<NllLossBackward>)
# tensor(-0.2913, grad_fn=<NllLossBackward>)
# tensor(-0.2917, grad_fn=<NllLossBackward>)
# tensor(-0.2921, grad_fn=<NllLossBackward>)
# tensor(-0.2925, grad_fn=<NllLossBackward>)
# tensor(-0.2929, grad_fn=<NllLossBackward>)
# tensor(-0.2932, grad_fn=<NllLossBackward>)
# tensor(-0.2936, grad_fn=<NllLossBackward>)
# tensor(-0.2940, grad_fn=<NllLossBackward>)
# tensor(-0.2944, grad_fn=<NllLossBackward>)
# tensor(-0.2947, grad_fn=<NllLossBackward>)
# tensor(-0.2951, grad_fn=<NllLossBackward>)
# tensor(-0.2955, grad_fn=<NllLossBackward>)
# tensor(-0.2959, grad_fn=<NllLossBackward>)
# tensor(-0.2962, grad_fn=<NllLossBackward>)
# tensor(-0.2966, grad_fn=<NllLossBackward>)
# tensor(-0.2970, grad_fn=<NllLossBackward>)
# tensor(-0.2974, grad_fn=<NllLossBackward>)
# tensor(-0.2978, grad_fn=<NllLossBackward>)
# tensor(-0.2981, grad_fn=<NllLossBackward>)
# tensor(-0.2985, grad_fn=<NllLossBackward>)
# tensor(-0.2989, grad_fn=<NllLossBackward>)
# tensor(-0.2993, grad_fn=<NllLossBackward>)
# tensor(-0.2996, grad_fn=<NllLossBackward>)
# tensor(-0.3000, grad_fn=<NllLossBackward>)
# tensor(-0.3004, grad_fn=<NllLossBackward>)
# tensor(-0.3008, grad_fn=<NllLossBackward>)
# tensor(-0.3012, grad_fn=<NllLossBackward>)
# tensor(-0.3015, grad_fn=<NllLossBackward>)
# tensor(-0.3019, grad_fn=<NllLossBackward>)
# tensor(-0.3023, grad_fn=<NllLossBackward>)
# tensor(-0.3027, grad_fn=<NllLossBackward>)
# tensor(-0.3030, grad_fn=<NllLossBackward>)
# tensor(-0.3034, grad_fn=<NllLossBackward>)
# tensor(-0.3038, grad_fn=<NllLossBackward>)
# tensor(-0.3042, grad_fn=<NllLossBackward>)
# tensor(-0.3045, grad_fn=<NllLossBackward>)
# tensor(-0.3049, grad_fn=<NllLossBackward>)
# tensor(-0.3053, grad_fn=<NllLossBackward>)
# tensor(-0.3057, grad_fn=<NllLossBackward>)
# tensor(-0.3060, grad_fn=<NllLossBackward>)
# tensor(-0.3064, grad_fn=<NllLossBackward>)
# tensor(-0.3068, grad_fn=<NllLossBackward>)
# tensor(-0.3072, grad_fn=<NllLossBackward>)
# tensor(-0.3076, grad_fn=<NllLossBackward>)
# tensor(-0.3079, grad_fn=<NllLossBackward>)
# tensor(-0.3083, grad_fn=<NllLossBackward>)
# tensor(-0.3087, grad_fn=<NllLossBackward>)
# tensor(-0.3091, grad_fn=<NllLossBackward>)
# tensor(-0.3094, grad_fn=<NllLossBackward>)
# tensor(-0.3098, grad_fn=<NllLossBackward>)
# tensor(-0.3102, grad_fn=<NllLossBackward>)
# tensor(-0.3106, grad_fn=<NllLossBackward>)
# tensor(-0.3109, grad_fn=<NllLossBackward>)
# tensor(-0.3113, grad_fn=<NllLossBackward>)
# tensor(-0.3117, grad_fn=<NllLossBackward>)
# tensor(-0.3121, grad_fn=<NllLossBackward>)
# tensor(-0.3124, grad_fn=<NllLossBackward>)
# tensor(-0.3128, grad_fn=<NllLossBackward>)
# tensor(-0.3132, grad_fn=<NllLossBackward>)
# tensor(-0.3136, grad_fn=<NllLossBackward>)
# tensor(-0.3139, grad_fn=<NllLossBackward>)
# tensor(-0.3143, grad_fn=<NllLossBackward>)
# tensor(-0.3147, grad_fn=<NllLossBackward>)
# tensor(-0.3151, grad_fn=<NllLossBackward>)
# tensor(-0.3154, grad_fn=<NllLossBackward>)
# tensor(-0.3158, grad_fn=<NllLossBackward>)
# tensor(-0.3162, grad_fn=<NllLossBackward>)
# tensor(-0.3166, grad_fn=<NllLossBackward>)
# tensor(-0.3169, grad_fn=<NllLossBackward>)
# tensor(-0.3173, grad_fn=<NllLossBackward>)
# tensor(-0.3177, grad_fn=<NllLossBackward>)
# tensor(-0.3181, grad_fn=<NllLossBackward>)
# tensor(-0.3184, grad_fn=<NllLossBackward>)
# tensor(-0.3188, grad_fn=<NllLossBackward>)
# tensor(-0.3192, grad_fn=<NllLossBackward>)
# tensor(-0.3196, grad_fn=<NllLossBackward>)
# tensor(-0.3199, grad_fn=<NllLossBackward>)
# tensor(-0.3203, grad_fn=<NllLossBackward>)
# tensor(-0.3207, grad_fn=<NllLossBackward>)
# tensor(-0.3210, grad_fn=<NllLossBackward>)
# tensor(-0.3214, grad_fn=<NllLossBackward>)
# tensor(-0.3218, grad_fn=<NllLossBackward>)
# tensor(-0.3222, grad_fn=<NllLossBackward>)
# tensor(-0.3225, grad_fn=<NllLossBackward>)
# tensor(-0.3229, grad_fn=<NllLossBackward>)
# tensor(-0.3233, grad_fn=<NllLossBackward>)
# tensor(-0.3237, grad_fn=<NllLossBackward>)
# tensor(-0.3240, grad_fn=<NllLossBackward>)
# tensor(-0.3244, grad_fn=<NllLossBackward>)
# tensor(-0.3248, grad_fn=<NllLossBackward>)
# tensor(-0.3251, grad_fn=<NllLossBackward>)
# tensor(-0.3255, grad_fn=<NllLossBackward>)
# tensor(-0.3259, grad_fn=<NllLossBackward>)
# tensor(-0.3263, grad_fn=<NllLossBackward>)
# tensor(-0.3266, grad_fn=<NllLossBackward>)
# tensor(-0.3270, grad_fn=<NllLossBackward>)
# tensor(-0.3274, grad_fn=<NllLossBackward>)
# tensor(-0.3277, grad_fn=<NllLossBackward>)
# tensor(-0.3281, grad_fn=<NllLossBackward>)
# tensor(-0.3285, grad_fn=<NllLossBackward>)
# tensor(-0.3289, grad_fn=<NllLossBackward>)
# tensor(-0.3292, grad_fn=<NllLossBackward>)
# tensor(-0.3296, grad_fn=<NllLossBackward>)
# tensor(-0.3300, grad_fn=<NllLossBackward>)
# tensor(-0.3303, grad_fn=<NllLossBackward>)
# tensor(-0.3307, grad_fn=<NllLossBackward>)
# tensor(-0.3311, grad_fn=<NllLossBackward>)
# tensor(-0.3314, grad_fn=<NllLossBackward>)
# tensor(-0.3318, grad_fn=<NllLossBackward>)
# tensor(-0.3322, grad_fn=<NllLossBackward>)
# tensor(-0.3326, grad_fn=<NllLossBackward>)
# tensor(-0.3329, grad_fn=<NllLossBackward>)
# tensor(-0.3333, grad_fn=<NllLossBackward>)
# tensor(-0.3337, grad_fn=<NllLossBackward>)
# tensor(-0.3340, grad_fn=<NllLossBackward>)
# tensor(-0.3344, grad_fn=<NllLossBackward>)
# tensor(-0.3348, grad_fn=<NllLossBackward>)
# tensor(-0.3351, grad_fn=<NllLossBackward>)
# tensor(-0.3355, grad_fn=<NllLossBackward>)
# tensor(-0.3359, grad_fn=<NllLossBackward>)
# tensor(-0.3362, grad_fn=<NllLossBackward>)
# tensor(-0.3366, grad_fn=<NllLossBackward>)
# tensor(-0.3370, grad_fn=<NllLossBackward>)
# tensor(-0.3373, grad_fn=<NllLossBackward>)
# tensor(-0.3377, grad_fn=<NllLossBackward>)
# tensor(-0.3381, grad_fn=<NllLossBackward>)
# tensor(-0.3384, grad_fn=<NllLossBackward>)
# tensor(-0.3388, grad_fn=<NllLossBackward>)
# tensor(-0.3392, grad_fn=<NllLossBackward>)
# tensor(-0.3395, grad_fn=<NllLossBackward>)
# tensor(-0.3399, grad_fn=<NllLossBackward>)
# tensor(-0.3403, grad_fn=<NllLossBackward>)
# tensor(-0.3406, grad_fn=<NllLossBackward>)
# tensor(-0.3410, grad_fn=<NllLossBackward>)
# tensor(-0.3414, grad_fn=<NllLossBackward>)
# tensor(-0.3417, grad_fn=<NllLossBackward>)
# tensor(-0.3421, grad_fn=<NllLossBackward>)
# tensor(-0.3425, grad_fn=<NllLossBackward>)
# tensor(-0.3428, grad_fn=<NllLossBackward>)
# tensor(-0.3432, grad_fn=<NllLossBackward>)
# tensor(-0.3435, grad_fn=<NllLossBackward>)
# tensor(-0.3439, grad_fn=<NllLossBackward>)
# tensor(-0.3443, grad_fn=<NllLossBackward>)
# tensor(-0.3446, grad_fn=<NllLossBackward>)
# tensor(-0.3450, grad_fn=<NllLossBackward>)
# tensor(-0.3454, grad_fn=<NllLossBackward>)
# tensor(-0.3457, grad_fn=<NllLossBackward>)
# tensor(-0.3461, grad_fn=<NllLossBackward>)
# tensor(-0.3464, grad_fn=<NllLossBackward>)
# tensor(-0.3468, grad_fn=<NllLossBackward>)
# tensor(-0.3472, grad_fn=<NllLossBackward>)
# tensor(-0.3475, grad_fn=<NllLossBackward>)
# tensor(-0.3479, grad_fn=<NllLossBackward>)
# tensor(-0.3483, grad_fn=<NllLossBackward>)
# tensor(-0.3486, grad_fn=<NllLossBackward>)
# tensor(-0.3490, grad_fn=<NllLossBackward>)
# tensor(-0.3493, grad_fn=<NllLossBackward>)
# tensor(-0.3497, grad_fn=<NllLossBackward>)
# tensor(-0.3501, grad_fn=<NllLossBackward>)
# tensor(-0.3504, grad_fn=<NllLossBackward>)
# tensor(-0.3508, grad_fn=<NllLossBackward>)
# tensor(-0.3511, grad_fn=<NllLossBackward>)
# tensor(-0.3515, grad_fn=<NllLossBackward>)
# tensor(-0.3519, grad_fn=<NllLossBackward>)
# tensor(-0.3522, grad_fn=<NllLossBackward>)
# tensor(-0.3526, grad_fn=<NllLossBackward>)
# tensor(-0.3529, grad_fn=<NllLossBackward>)
# tensor(-0.3533, grad_fn=<NllLossBackward>)
# tensor(-0.3536, grad_fn=<NllLossBackward>)
# tensor(-0.3540, grad_fn=<NllLossBackward>)
# tensor(-0.3544, grad_fn=<NllLossBackward>)
# tensor(-0.3547, grad_fn=<NllLossBackward>)
# tensor(-0.3551, grad_fn=<NllLossBackward>)
# tensor(-0.3554, grad_fn=<NllLossBackward>)
# tensor(-0.3558, grad_fn=<NllLossBackward>)
# tensor(-0.3562, grad_fn=<NllLossBackward>)
# tensor(-0.3565, grad_fn=<NllLossBackward>)
# tensor(-0.3569, grad_fn=<NllLossBackward>)
# tensor(-0.3572, grad_fn=<NllLossBackward>)
# tensor(-0.3576, grad_fn=<NllLossBackward>)
# tensor(-0.3579, grad_fn=<NllLossBackward>)
# tensor(-0.3583, grad_fn=<NllLossBackward>)
# tensor(-0.3586, grad_fn=<NllLossBackward>)
# tensor(-0.3590, grad_fn=<NllLossBackward>)
# tensor(-0.3593, grad_fn=<NllLossBackward>)
# tensor(-0.3597, grad_fn=<NllLossBackward>)
# tensor(-0.3601, grad_fn=<NllLossBackward>)
# tensor(-0.3604, grad_fn=<NllLossBackward>)
# tensor(-0.3608, grad_fn=<NllLossBackward>)
# tensor(-0.3611, grad_fn=<NllLossBackward>)
# tensor(-0.3615, grad_fn=<NllLossBackward>)
# tensor(-0.3618, grad_fn=<NllLossBackward>)
# tensor(-0.3622, grad_fn=<NllLossBackward>)
# tensor(-0.3625, grad_fn=<NllLossBackward>)
# tensor(-0.3629, grad_fn=<NllLossBackward>)
# tensor(-0.3632, grad_fn=<NllLossBackward>)
# tensor(-0.3636, grad_fn=<NllLossBackward>)
# tensor(-0.3639, grad_fn=<NllLossBackward>)
# tensor(-0.3643, grad_fn=<NllLossBackward>)
# tensor(-0.3646, grad_fn=<NllLossBackward>)
# tensor(-0.3650, grad_fn=<NllLossBackward>)
# tensor(-0.3653, grad_fn=<NllLossBackward>)
# tensor(-0.3657, grad_fn=<NllLossBackward>)
# tensor(-0.3660, grad_fn=<NllLossBackward>)
# tensor(-0.3664, grad_fn=<NllLossBackward>)
# tensor(-0.3667, grad_fn=<NllLossBackward>)
# tensor(-0.3671, grad_fn=<NllLossBackward>)
# tensor(-0.3674, grad_fn=<NllLossBackward>)
# tensor(-0.3678, grad_fn=<NllLossBackward>)
# tensor(-0.3681, grad_fn=<NllLossBackward>)
# tensor(-0.3685, grad_fn=<NllLossBackward>)
# tensor(-0.3688, grad_fn=<NllLossBackward>)
# tensor(-0.3692, grad_fn=<NllLossBackward>)
# tensor(-0.3695, grad_fn=<NllLossBackward>)
# tensor(-0.3699, grad_fn=<NllLossBackward>)
# tensor(-0.3702, grad_fn=<NllLossBackward>)
# tensor(-0.3706, grad_fn=<NllLossBackward>)
# tensor(-0.3709, grad_fn=<NllLossBackward>)
# tensor(-0.3713, grad_fn=<NllLossBackward>)
# tensor(-0.3716, grad_fn=<NllLossBackward>)
# tensor(-0.3720, grad_fn=<NllLossBackward>)
# tensor(-0.3723, grad_fn=<NllLossBackward>)
# tensor(-0.3726, grad_fn=<NllLossBackward>)
# tensor(-0.3730, grad_fn=<NllLossBackward>)
# tensor(-0.3733, grad_fn=<NllLossBackward>)
# tensor(-0.3737, grad_fn=<NllLossBackward>)
# tensor(-0.3740, grad_fn=<NllLossBackward>)
# tensor(-0.3744, grad_fn=<NllLossBackward>)
# tensor(-0.3747, grad_fn=<NllLossBackward>)
# tensor(-0.3750, grad_fn=<NllLossBackward>)
# tensor(-0.3754, grad_fn=<NllLossBackward>)
# tensor(-0.3757, grad_fn=<NllLossBackward>)
# tensor(-0.3761, grad_fn=<NllLossBackward>)
# tensor(-0.3764, grad_fn=<NllLossBackward>)
# tensor(-0.3768, grad_fn=<NllLossBackward>)
# tensor(-0.3771, grad_fn=<NllLossBackward>)
# tensor(-0.3774, grad_fn=<NllLossBackward>)
# tensor(-0.3778, grad_fn=<NllLossBackward>)
# tensor(-0.3781, grad_fn=<NllLossBackward>)
# tensor(-0.3785, grad_fn=<NllLossBackward>)
# tensor(-0.3788, grad_fn=<NllLossBackward>)
# tensor(-0.3791, grad_fn=<NllLossBackward>)
# tensor(-0.3795, grad_fn=<NllLossBackward>)
# tensor(-0.3798, grad_fn=<NllLossBackward>)
# tensor(-0.3802, grad_fn=<NllLossBackward>)
# tensor(-0.3805, grad_fn=<NllLossBackward>)
# tensor(-0.3808, grad_fn=<NllLossBackward>)
# tensor(-0.3812, grad_fn=<NllLossBackward>)
# tensor(-0.3815, grad_fn=<NllLossBackward>)
# tensor(-0.3819, grad_fn=<NllLossBackward>)
# tensor(-0.3822, grad_fn=<NllLossBackward>)
# tensor(-0.3825, grad_fn=<NllLossBackward>)
# tensor(-0.3829, grad_fn=<NllLossBackward>)
# tensor(-0.3832, grad_fn=<NllLossBackward>)
# tensor(-0.3835, grad_fn=<NllLossBackward>)
# tensor(-0.3839, grad_fn=<NllLossBackward>)
# tensor(-0.3842, grad_fn=<NllLossBackward>)
# tensor(-0.3845, grad_fn=<NllLossBackward>)
# tensor(-0.3849, grad_fn=<NllLossBackward>)
# tensor(-0.3852, grad_fn=<NllLossBackward>)
# tensor(-0.3856, grad_fn=<NllLossBackward>)
# tensor(-0.3859, grad_fn=<NllLossBackward>)
# tensor(-0.3862, grad_fn=<NllLossBackward>)
# tensor(-0.3866, grad_fn=<NllLossBackward>)
# tensor(-0.3869, grad_fn=<NllLossBackward>)
# tensor(-0.3872, grad_fn=<NllLossBackward>)
# tensor(-0.3876, grad_fn=<NllLossBackward>)
# tensor(-0.3879, grad_fn=<NllLossBackward>)
# tensor(-0.3882, grad_fn=<NllLossBackward>)
# tensor(-0.3886, grad_fn=<NllLossBackward>)
# tensor(-0.3889, grad_fn=<NllLossBackward>)
# tensor(-0.3892, grad_fn=<NllLossBackward>)
# tensor(-0.3895, grad_fn=<NllLossBackward>)
# tensor(-0.3899, grad_fn=<NllLossBackward>)
# tensor(-0.3902, grad_fn=<NllLossBackward>)
# tensor(-0.3905, grad_fn=<NllLossBackward>)
# tensor(-0.3909, grad_fn=<NllLossBackward>)
# tensor(-0.3912, grad_fn=<NllLossBackward>)
# tensor(-0.3915, grad_fn=<NllLossBackward>)
# tensor(-0.3919, grad_fn=<NllLossBackward>)
# tensor(-0.3922, grad_fn=<NllLossBackward>)
# tensor(-0.3925, grad_fn=<NllLossBackward>)
# tensor(-0.3928, grad_fn=<NllLossBackward>)
# tensor(-0.3932, grad_fn=<NllLossBackward>)
# tensor(-0.3935, grad_fn=<NllLossBackward>)
# tensor(-0.3938, grad_fn=<NllLossBackward>)
# tensor(-0.3941, grad_fn=<NllLossBackward>)
# tensor(-0.3945, grad_fn=<NllLossBackward>)
# tensor(-0.3948, grad_fn=<NllLossBackward>)
# tensor(-0.3951, grad_fn=<NllLossBackward>)
# tensor(-0.3955, grad_fn=<NllLossBackward>)
# tensor(-0.3958, grad_fn=<NllLossBackward>)
# tensor(-0.3961, grad_fn=<NllLossBackward>)
# tensor(-0.3964, grad_fn=<NllLossBackward>)
# tensor(-0.3968, grad_fn=<NllLossBackward>)
# tensor(-0.3971, grad_fn=<NllLossBackward>)
# tensor(-0.3974, grad_fn=<NllLossBackward>)
# tensor(-0.3977, grad_fn=<NllLossBackward>)
# tensor(-0.3980, grad_fn=<NllLossBackward>)
# tensor(-0.3984, grad_fn=<NllLossBackward>)
# tensor(-0.3987, grad_fn=<NllLossBackward>)
# tensor(-0.3990, grad_fn=<NllLossBackward>)
# tensor(-0.3993, grad_fn=<NllLossBackward>)
# tensor(-0.3997, grad_fn=<NllLossBackward>)
# tensor(-0.4000, grad_fn=<NllLossBackward>)
# tensor(-0.4003, grad_fn=<NllLossBackward>)
# tensor(-0.4006, grad_fn=<NllLossBackward>)
# tensor(-0.4009, grad_fn=<NllLossBackward>)
# tensor(-0.4013, grad_fn=<NllLossBackward>)
# tensor(-0.4016, grad_fn=<NllLossBackward>)
# tensor(-0.4019, grad_fn=<NllLossBackward>)
# tensor(-0.4022, grad_fn=<NllLossBackward>)
# tensor(-0.4025, grad_fn=<NllLossBackward>)
# tensor(-0.4029, grad_fn=<NllLossBackward>)
# tensor(-0.4032, grad_fn=<NllLossBackward>)
# tensor(-0.4035, grad_fn=<NllLossBackward>)
# tensor(-0.4038, grad_fn=<NllLossBackward>)
# tensor(-0.4041, grad_fn=<NllLossBackward>)
# tensor(-0.4044, grad_fn=<NllLossBackward>)
# tensor(-0.4048, grad_fn=<NllLossBackward>)
# tensor(-0.4051, grad_fn=<NllLossBackward>)
# tensor(-0.4054, grad_fn=<NllLossBackward>)
# tensor(-0.4057, grad_fn=<NllLossBackward>)
# tensor(-0.4060, grad_fn=<NllLossBackward>)
# tensor(-0.4063, grad_fn=<NllLossBackward>)
# tensor(-0.4066, grad_fn=<NllLossBackward>)
# tensor(-0.4070, grad_fn=<NllLossBackward>)
# tensor(-0.4073, grad_fn=<NllLossBackward>)
# tensor(-0.4076, grad_fn=<NllLossBackward>)
# tensor(-0.4079, grad_fn=<NllLossBackward>)
# tensor(-0.4082, grad_fn=<NllLossBackward>)
# tensor(-0.4085, grad_fn=<NllLossBackward>)
# tensor(-0.4088, grad_fn=<NllLossBackward>)
# tensor(-0.4092, grad_fn=<NllLossBackward>)
# tensor(-0.4095, grad_fn=<NllLossBackward>)
# tensor(-0.4098, grad_fn=<NllLossBackward>)
# tensor(-0.4101, grad_fn=<NllLossBackward>)
# tensor(-0.4104, grad_fn=<NllLossBackward>)
# tensor(-0.4107, grad_fn=<NllLossBackward>)
# tensor(-0.4110, grad_fn=<NllLossBackward>)
# tensor(-0.4113, grad_fn=<NllLossBackward>)
# tensor(-0.4116, grad_fn=<NllLossBackward>)
# tensor(-0.4119, grad_fn=<NllLossBackward>)
# tensor(-0.4123, grad_fn=<NllLossBackward>)
# tensor(-0.4126, grad_fn=<NllLossBackward>)
# tensor(-0.4129, grad_fn=<NllLossBackward>)
# tensor(-0.4132, grad_fn=<NllLossBackward>)
# tensor(-0.4135, grad_fn=<NllLossBackward>)
# tensor(-0.4138, grad_fn=<NllLossBackward>)
# tensor(-0.4141, grad_fn=<NllLossBackward>)
# tensor(-0.4144, grad_fn=<NllLossBackward>)
# tensor(-0.4147, grad_fn=<NllLossBackward>)
# tensor(-0.4150, grad_fn=<NllLossBackward>)
# tensor(-0.4153, grad_fn=<NllLossBackward>)
# tensor(-0.4156, grad_fn=<NllLossBackward>)
# tensor(-0.4159, grad_fn=<NllLossBackward>)
# tensor(-0.4162, grad_fn=<NllLossBackward>)
# tensor(-0.4165, grad_fn=<NllLossBackward>)
# tensor(-0.4168, grad_fn=<NllLossBackward>)
# tensor(-0.4171, grad_fn=<NllLossBackward>)
# tensor(-0.4174, grad_fn=<NllLossBackward>)
# tensor(-0.4178, grad_fn=<NllLossBackward>)
# tensor(-0.4181, grad_fn=<NllLossBackward>)
# tensor(-0.4184, grad_fn=<NllLossBackward>)
# tensor(-0.4187, grad_fn=<NllLossBackward>)
# tensor(-0.4190, grad_fn=<NllLossBackward>)
# tensor(-0.4193, grad_fn=<NllLossBackward>)
# tensor(-0.4196, grad_fn=<NllLossBackward>)
# tensor(-0.4199, grad_fn=<NllLossBackward>)
# tensor(-0.4202, grad_fn=<NllLossBackward>)
# tensor(-0.4205, grad_fn=<NllLossBackward>)
# tensor(-0.4208, grad_fn=<NllLossBackward>)
# tensor(-0.4211, grad_fn=<NllLossBackward>)
# tensor(-0.4214, grad_fn=<NllLossBackward>)
# tensor(-0.4217, grad_fn=<NllLossBackward>)
# tensor(-0.4220, grad_fn=<NllLossBackward>)
# tensor(-0.4222, grad_fn=<NllLossBackward>)
# tensor(-0.4225, grad_fn=<NllLossBackward>)
# tensor(-0.4228, grad_fn=<NllLossBackward>)
# tensor(-0.4231, grad_fn=<NllLossBackward>)
# tensor(-0.4234, grad_fn=<NllLossBackward>)
# tensor(-0.4237, grad_fn=<NllLossBackward>)
# tensor(-0.4240, grad_fn=<NllLossBackward>)
# tensor(-0.4243, grad_fn=<NllLossBackward>)
# tensor(-0.4246, grad_fn=<NllLossBackward>)
# tensor(-0.4249, grad_fn=<NllLossBackward>)
# tensor(-0.4252, grad_fn=<NllLossBackward>)
# tensor(-0.4255, grad_fn=<NllLossBackward>)
# tensor(-0.4258, grad_fn=<NllLossBackward>)
# tensor(-0.4261, grad_fn=<NllLossBackward>)
# tensor(-0.4264, grad_fn=<NllLossBackward>)
# tensor(-0.4267, grad_fn=<NllLossBackward>)
# tensor(-0.4270, grad_fn=<NllLossBackward>)
# tensor(-0.4273, grad_fn=<NllLossBackward>)
# tensor(-0.4275, grad_fn=<NllLossBackward>)
# tensor(-0.4278, grad_fn=<NllLossBackward>)
# tensor(-0.4281, grad_fn=<NllLossBackward>)
# tensor(-0.4284, grad_fn=<NllLossBackward>)
# tensor(-0.4287, grad_fn=<NllLossBackward>)
# tensor(-0.4290, grad_fn=<NllLossBackward>)
# tensor(-0.4293, grad_fn=<NllLossBackward>)
# tensor(-0.4296, grad_fn=<NllLossBackward>)
# tensor(-0.4299, grad_fn=<NllLossBackward>)
# tensor(-0.4302, grad_fn=<NllLossBackward>)
# tensor(-0.4304, grad_fn=<NllLossBackward>)
# tensor(-0.4307, grad_fn=<NllLossBackward>)
# tensor(-0.4310, grad_fn=<NllLossBackward>)
# tensor(-0.4313, grad_fn=<NllLossBackward>)
# tensor(-0.4316, grad_fn=<NllLossBackward>)
# tensor(-0.4319, grad_fn=<NllLossBackward>)
# tensor(-0.4322, grad_fn=<NllLossBackward>)
# tensor(-0.4324, grad_fn=<NllLossBackward>)
# tensor(-0.4327, grad_fn=<NllLossBackward>)
# tensor(-0.4330, grad_fn=<NllLossBackward>)
# tensor(-0.4333, grad_fn=<NllLossBackward>)
# tensor(-0.4336, grad_fn=<NllLossBackward>)
# tensor(-0.4339, grad_fn=<NllLossBackward>)
# tensor(-0.4342, grad_fn=<NllLossBackward>)
# tensor(-0.4344, grad_fn=<NllLossBackward>)
# tensor(-0.4347, grad_fn=<NllLossBackward>)
# tensor(-0.4350, grad_fn=<NllLossBackward>)
# tensor(-0.4353, grad_fn=<NllLossBackward>)
# tensor(-0.4356, grad_fn=<NllLossBackward>)
# tensor(-0.4358, grad_fn=<NllLossBackward>)
# tensor(-0.4361, grad_fn=<NllLossBackward>)
# tensor(-0.4364, grad_fn=<NllLossBackward>)
# tensor(-0.4367, grad_fn=<NllLossBackward>)
# tensor(-0.4370, grad_fn=<NllLossBackward>)
# tensor(-0.4372, grad_fn=<NllLossBackward>)
# tensor(-0.4375, grad_fn=<NllLossBackward>)
# tensor(-0.4378, grad_fn=<NllLossBackward>)
# tensor(-0.4381, grad_fn=<NllLossBackward>)
# tensor(-0.4384, grad_fn=<NllLossBackward>)
# tensor(-0.4386, grad_fn=<NllLossBackward>)
# tensor(-0.4389, grad_fn=<NllLossBackward>)
# tensor(-0.4392, grad_fn=<NllLossBackward>)
# tensor(-0.4395, grad_fn=<NllLossBackward>)
# tensor(-0.4397, grad_fn=<NllLossBackward>)
# tensor(-0.4400, grad_fn=<NllLossBackward>)
# tensor(-0.4403, grad_fn=<NllLossBackward>)
# tensor(-0.4406, grad_fn=<NllLossBackward>)
# tensor(-0.4408, grad_fn=<NllLossBackward>)
# tensor(-0.4411, grad_fn=<NllLossBackward>)
# tensor(-0.4414, grad_fn=<NllLossBackward>)
# tensor(-0.4417, grad_fn=<NllLossBackward>)
# tensor(-0.4419, grad_fn=<NllLossBackward>)
# tensor(-0.4422, grad_fn=<NllLossBackward>)
# tensor(-0.4425, grad_fn=<NllLossBackward>)
# tensor(-0.4428, grad_fn=<NllLossBackward>)
# tensor(-0.4430, grad_fn=<NllLossBackward>)
# tensor(-0.4433, grad_fn=<NllLossBackward>)
# tensor(-0.4436, grad_fn=<NllLossBackward>)
# tensor(-0.4438, grad_fn=<NllLossBackward>)
# tensor(-0.4441, grad_fn=<NllLossBackward>)
# tensor(-0.4444, grad_fn=<NllLossBackward>)
# tensor(-0.4447, grad_fn=<NllLossBackward>)
# tensor(-0.4449, grad_fn=<NllLossBackward>)
# tensor(-0.4452, grad_fn=<NllLossBackward>)
# tensor(-0.4455, grad_fn=<NllLossBackward>)
# tensor(-0.4457, grad_fn=<NllLossBackward>)
# tensor(-0.4460, grad_fn=<NllLossBackward>)
# tensor(-0.4463, grad_fn=<NllLossBackward>)
# tensor(-0.4465, grad_fn=<NllLossBackward>)
# tensor(-0.4468, grad_fn=<NllLossBackward>)
# tensor(-0.4471, grad_fn=<NllLossBackward>)
# tensor(-0.4473, grad_fn=<NllLossBackward>)
# tensor(-0.4476, grad_fn=<NllLossBackward>)
# tensor(-0.4479, grad_fn=<NllLossBackward>)
# tensor(-0.4481, grad_fn=<NllLossBackward>)
# tensor(-0.4484, grad_fn=<NllLossBackward>)
# tensor(-0.4487, grad_fn=<NllLossBackward>)
# tensor(-0.4489, grad_fn=<NllLossBackward>)
# tensor(-0.4492, grad_fn=<NllLossBackward>)
# tensor(-0.4495, grad_fn=<NllLossBackward>)
# tensor(-0.4497, grad_fn=<NllLossBackward>)
# tensor(-0.4500, grad_fn=<NllLossBackward>)
# tensor(-0.4503, grad_fn=<NllLossBackward>)
# tensor(-0.4505, grad_fn=<NllLossBackward>)
# tensor(-0.4508, grad_fn=<NllLossBackward>)
# tensor(-0.4510, grad_fn=<NllLossBackward>)
# tensor(-0.4513, grad_fn=<NllLossBackward>)
# tensor(-0.4516, grad_fn=<NllLossBackward>)
# tensor(-0.4518, grad_fn=<NllLossBackward>)
# tensor(-0.4521, grad_fn=<NllLossBackward>)
# tensor(-0.4523, grad_fn=<NllLossBackward>)
# tensor(-0.4526, grad_fn=<NllLossBackward>)
# tensor(-0.4529, grad_fn=<NllLossBackward>)
# tensor(-0.4531, grad_fn=<NllLossBackward>)
# tensor(-0.4534, grad_fn=<NllLossBackward>)
# tensor(-0.4536, grad_fn=<NllLossBackward>)
# tensor(-0.4539, grad_fn=<NllLossBackward>)
# tensor(-0.4542, grad_fn=<NllLossBackward>)
# tensor(-0.4544, grad_fn=<NllLossBackward>)
# tensor(-0.4547, grad_fn=<NllLossBackward>)
# tensor(-0.4549, grad_fn=<NllLossBackward>)
# tensor(-0.4552, grad_fn=<NllLossBackward>)
# tensor(-0.4554, grad_fn=<NllLossBackward>)
# tensor(-0.4557, grad_fn=<NllLossBackward>)
# tensor(-0.4559, grad_fn=<NllLossBackward>)
# tensor(-0.4562, grad_fn=<NllLossBackward>)
# tensor(-0.4565, grad_fn=<NllLossBackward>)
# tensor(-0.4567, grad_fn=<NllLossBackward>)
# tensor(-0.4570, grad_fn=<NllLossBackward>)
# tensor(-0.4572, grad_fn=<NllLossBackward>)
# tensor(-0.4575, grad_fn=<NllLossBackward>)
# tensor(-0.4577, grad_fn=<NllLossBackward>)
# tensor(-0.4580, grad_fn=<NllLossBackward>)
# tensor(-0.4582, grad_fn=<NllLossBackward>)
# tensor(-0.4585, grad_fn=<NllLossBackward>)
# tensor(-0.4587, grad_fn=<NllLossBackward>)
# tensor(-0.4590, grad_fn=<NllLossBackward>)
# tensor(-0.4592, grad_fn=<NllLossBackward>)
# tensor(-0.4595, grad_fn=<NllLossBackward>)
# tensor(-0.4597, grad_fn=<NllLossBackward>)
# tensor(-0.4600, grad_fn=<NllLossBackward>)
# tensor(-0.4602, grad_fn=<NllLossBackward>)
# tensor(-0.4605, grad_fn=<NllLossBackward>)
# tensor(-0.4607, grad_fn=<NllLossBackward>)
# tensor(-0.4610, grad_fn=<NllLossBackward>)
# tensor(-0.4612, grad_fn=<NllLossBackward>)
# tensor(-0.4615, grad_fn=<NllLossBackward>)
# tensor(-0.4617, grad_fn=<NllLossBackward>)
# tensor(-0.4620, grad_fn=<NllLossBackward>)
# tensor(-0.4622, grad_fn=<NllLossBackward>)
# tensor(-0.4625, grad_fn=<NllLossBackward>)
# tensor(-0.4627, grad_fn=<NllLossBackward>)
# tensor(-0.4629, grad_fn=<NllLossBackward>)
# tensor(-0.4632, grad_fn=<NllLossBackward>)
# tensor(-0.4634, grad_fn=<NllLossBackward>)
# tensor(-0.4637, grad_fn=<NllLossBackward>)
# tensor(-0.4639, grad_fn=<NllLossBackward>)
# tensor(-0.4642, grad_fn=<NllLossBackward>)
# tensor(-0.4644, grad_fn=<NllLossBackward>)
# tensor(-0.4647, grad_fn=<NllLossBackward>)
# tensor(-0.4649, grad_fn=<NllLossBackward>)
# tensor(-0.4651, grad_fn=<NllLossBackward>)
# tensor(-0.4654, grad_fn=<NllLossBackward>)
# tensor(-0.4656, grad_fn=<NllLossBackward>)
# tensor(-0.4659, grad_fn=<NllLossBackward>)
# tensor(-0.4661, grad_fn=<NllLossBackward>)
# tensor(-0.4663, grad_fn=<NllLossBackward>)
# tensor(-0.4666, grad_fn=<NllLossBackward>)
# tensor(-0.4668, grad_fn=<NllLossBackward>)
# tensor(-0.4671, grad_fn=<NllLossBackward>)
# tensor(-0.4673, grad_fn=<NllLossBackward>)
# tensor(-0.4675, grad_fn=<NllLossBackward>)
# tensor(-0.4678, grad_fn=<NllLossBackward>)
# tensor(-0.4680, grad_fn=<NllLossBackward>)
# tensor(-0.4683, grad_fn=<NllLossBackward>)
# tensor(-0.4685, grad_fn=<NllLossBackward>)
# tensor(-0.4687, grad_fn=<NllLossBackward>)
# tensor(-0.4690, grad_fn=<NllLossBackward>)
# tensor(-0.4692, grad_fn=<NllLossBackward>)
# tensor(-0.4694, grad_fn=<NllLossBackward>)
# tensor(-0.4697, grad_fn=<NllLossBackward>)
# tensor(-0.4699, grad_fn=<NllLossBackward>)
# tensor(-0.4701, grad_fn=<NllLossBackward>)
# tensor(-0.4704, grad_fn=<NllLossBackward>)
# tensor(-0.4706, grad_fn=<NllLossBackward>)
# tensor(-0.4709, grad_fn=<NllLossBackward>)
# tensor(-0.4711, grad_fn=<NllLossBackward>)
# tensor(-0.4713, grad_fn=<NllLossBackward>)
# tensor(-0.4716, grad_fn=<NllLossBackward>)
# tensor(-0.4718, grad_fn=<NllLossBackward>)
# tensor(-0.4720, grad_fn=<NllLossBackward>)
# tensor(-0.4723, grad_fn=<NllLossBackward>)
# tensor(-0.4725, grad_fn=<NllLossBackward>)
# tensor(-0.4727, grad_fn=<NllLossBackward>)
# tensor(-0.4729, grad_fn=<NllLossBackward>)
# tensor(-0.4732, grad_fn=<NllLossBackward>)
# tensor(-0.4734, grad_fn=<NllLossBackward>)
# tensor(-0.4736, grad_fn=<NllLossBackward>)
# tensor(-0.4739, grad_fn=<NllLossBackward>)
# tensor(-0.4741, grad_fn=<NllLossBackward>)
# tensor(-0.4743, grad_fn=<NllLossBackward>)
# tensor(-0.4746, grad_fn=<NllLossBackward>)
# tensor(-0.4748, grad_fn=<NllLossBackward>)
# tensor(-0.4750, grad_fn=<NllLossBackward>)
# tensor(-0.4752, grad_fn=<NllLossBackward>)
# tensor(-0.4755, grad_fn=<NllLossBackward>)
# tensor(-0.4757, grad_fn=<NllLossBackward>)
# tensor(-0.4759, grad_fn=<NllLossBackward>)
# tensor(-0.4761, grad_fn=<NllLossBackward>)
# tensor(-0.4764, grad_fn=<NllLossBackward>)
# tensor(-0.4766, grad_fn=<NllLossBackward>)
# tensor(-0.4768, grad_fn=<NllLossBackward>)
# tensor(-0.4770, grad_fn=<NllLossBackward>)
# tensor(-0.4773, grad_fn=<NllLossBackward>)
# tensor(-0.4775, grad_fn=<NllLossBackward>)
# tensor(-0.4777, grad_fn=<NllLossBackward>)
# tensor(-0.4779, grad_fn=<NllLossBackward>)
# tensor(-0.4782, grad_fn=<NllLossBackward>)
# tensor(-0.4784, grad_fn=<NllLossBackward>)
# tensor(-0.4786, grad_fn=<NllLossBackward>)
# tensor(-0.4788, grad_fn=<NllLossBackward>)
# tensor(-0.4791, grad_fn=<NllLossBackward>)
# tensor(-0.4793, grad_fn=<NllLossBackward>)
# tensor(-0.4795, grad_fn=<NllLossBackward>)
# tensor(-0.4797, grad_fn=<NllLossBackward>)
# tensor(-0.4799, grad_fn=<NllLossBackward>)
# tensor(-0.4802, grad_fn=<NllLossBackward>)
# tensor(-0.4804, grad_fn=<NllLossBackward>)
# tensor(-0.4806, grad_fn=<NllLossBackward>)
# tensor(-0.4808, grad_fn=<NllLossBackward>)
# tensor(-0.4810, grad_fn=<NllLossBackward>)
# tensor(-0.4813, grad_fn=<NllLossBackward>)
# tensor(-0.4815, grad_fn=<NllLossBackward>)
# tensor(-0.4817, grad_fn=<NllLossBackward>)
# tensor(-0.4819, grad_fn=<NllLossBackward>)
# tensor(-0.4821, grad_fn=<NllLossBackward>)
# tensor(-0.4824, grad_fn=<NllLossBackward>)
# tensor(-0.4826, grad_fn=<NllLossBackward>)
# tensor(-0.4828, grad_fn=<NllLossBackward>)
# tensor(-0.4830, grad_fn=<NllLossBackward>)
# tensor(-0.4832, grad_fn=<NllLossBackward>)
# tensor(-0.4834, grad_fn=<NllLossBackward>)
# tensor(-0.4836, grad_fn=<NllLossBackward>)
# tensor(-0.4839, grad_fn=<NllLossBackward>)
# tensor(-0.4841, grad_fn=<NllLossBackward>)
# tensor(-0.4843, grad_fn=<NllLossBackward>)
# tensor(-0.4845, grad_fn=<NllLossBackward>)
# tensor(-0.4847, grad_fn=<NllLossBackward>)
# tensor(-0.4849, grad_fn=<NllLossBackward>)
# tensor(-0.4851, grad_fn=<NllLossBackward>)
# tensor(-0.4854, grad_fn=<NllLossBackward>)
# tensor(-0.4856, grad_fn=<NllLossBackward>)
# tensor(-0.4858, grad_fn=<NllLossBackward>)
# tensor(-0.4860, grad_fn=<NllLossBackward>)
# tensor(-0.4862, grad_fn=<NllLossBackward>)
# tensor(-0.4864, grad_fn=<NllLossBackward>)
# tensor(-0.4866, grad_fn=<NllLossBackward>)
# tensor(-0.4868, grad_fn=<NllLossBackward>)
# tensor(-0.4871, grad_fn=<NllLossBackward>)
# tensor(-0.4873, grad_fn=<NllLossBackward>)
# tensor(-0.4875, grad_fn=<NllLossBackward>)
# tensor(-0.4877, grad_fn=<NllLossBackward>)
# tensor(-0.4879, grad_fn=<NllLossBackward>)
# tensor(-0.4881, grad_fn=<NllLossBackward>)
# tensor(-0.4883, grad_fn=<NllLossBackward>)
# tensor(-0.4885, grad_fn=<NllLossBackward>)
# tensor(-0.4887, grad_fn=<NllLossBackward>)
# tensor(-0.4889, grad_fn=<NllLossBackward>)
# tensor(-0.4891, grad_fn=<NllLossBackward>)
# tensor(-0.4893, grad_fn=<NllLossBackward>)
# tensor(-0.4895, grad_fn=<NllLossBackward>)
# tensor(-0.4898, grad_fn=<NllLossBackward>)
# tensor(-0.4900, grad_fn=<NllLossBackward>)
# tensor(-0.4902, grad_fn=<NllLossBackward>)
# tensor(-0.4904, grad_fn=<NllLossBackward>)
# tensor(-0.4906, grad_fn=<NllLossBackward>)
# tensor(-0.4908, grad_fn=<NllLossBackward>)
# tensor(-0.4910, grad_fn=<NllLossBackward>)
# tensor(-0.4912, grad_fn=<NllLossBackward>)
# tensor(-0.4914, grad_fn=<NllLossBackward>)
# tensor(-0.4916, grad_fn=<NllLossBackward>)
# tensor(-0.4918, grad_fn=<NllLossBackward>)
# tensor(-0.4920, grad_fn=<NllLossBackward>)
# tensor(-0.4922, grad_fn=<NllLossBackward>)
# tensor(-0.4924, grad_fn=<NllLossBackward>)
# tensor(-0.4926, grad_fn=<NllLossBackward>)
# tensor(-0.4928, grad_fn=<NllLossBackward>)
# tensor(-0.4930, grad_fn=<NllLossBackward>)
# tensor(-0.4932, grad_fn=<NllLossBackward>)
# tensor(-0.4934, grad_fn=<NllLossBackward>)
# tensor(-0.4936, grad_fn=<NllLossBackward>)
# tensor(-0.4938, grad_fn=<NllLossBackward>)
# tensor(-0.4940, grad_fn=<NllLossBackward>)
# tensor(-0.4942, grad_fn=<NllLossBackward>)
# tensor(-0.4944, grad_fn=<NllLossBackward>)
# tensor(-0.4946, grad_fn=<NllLossBackward>)
# tensor(-0.4948, grad_fn=<NllLossBackward>)
# ...
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6391, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6392, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6393, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6394, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6395, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# tensor(-0.6396, grad_fn=<NllLossBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-173c68f743ac> in <module>()
#       1 for i in range(10000):
# ----> 2     loss = optimizer.step(closure)
#       3     print(loss)
#
# /Users/andrew/anaconda/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      55         loss = None
#      56         if closure is not None:
# ---> 57             loss = closure()
#      58
#      59         for group in self.param_groups:
#
# <ipython-input-160-98392810f435> in closure()
#      10 def closure():
#      11     optimizer.zero_grad()
# ---> 12     pred1 = model(X)
#      13     pointer_loss = nn.functional.nll_loss(pred1, pointer_outputs)
#      14     loss = pointer_loss
#
# /Users/andrew/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-157-29e1ba96c86b> in forward(self, x)
#      13         for x_t in x.reshape(len(x), 1, self.input_dim):
#      14 #             h_t, c_t = self.lstm(x_t, (h_t, c_t))
# ---> 15             pointer_outputs.append(self.softmax(self.lin_pointer(x_t)))
#      16
#      17         return torch.stack(pointer_outputs).reshape(len(x), self.pointer_dim)
#
# /Users/andrew/anaconda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# /Users/andrew/anaconda/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def extra_repr(self):
#
# /Users/andrew/anaconda/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1022     if input.dim() == 2 and bias is not None:
#    1023         # fused op is marginally faster
# -> 1024         return torch.addmm(bias, input, weight.t())
#    1025
#    1026     output = input.matmul(weight.t())
#
# KeyboardInterrupt:
